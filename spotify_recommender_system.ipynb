# %% [markdown]
# # Spotify Hybrid Recommendation Engine
#
# Building a hybrid music recommender that fuses collaborative filtering (SVD), content-based cosine similarity, and a real-time session layer.
#
# ## Pipeline overview:
# - Fetch real tracks and audio features from the Spotify Web API (with synthetic user interactions)
# - Validate data and run EDA
# - Preprocess: temporal train/val/test splits, sparse matrices, feature scaling
# - Train collaborative filter (TruncatedSVD) and content-based model (cosine similarity)
# - Fuse into weighted hybrid with cold-start handling
# - Re-rank with diversity constraints
# - Add real-time session personalization
# - Evaluate with Precision, Recall, NDCG, MAP, Hit Rate @K
#
# ## Stack I'm using:
# - spotipy for Spotify Web API access
# - pandas, numpy, scipy, scikit-learn
# - matplotlib for plots
# - joblib for serialization
# - FastAPI + uvicorn for serving (separate `pipeline.py`)

# %%
# !pip install -q pandas numpy scipy scikit-learn matplotlib joblib spotipy
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.8/409.8 kB 15.9 MB/s eta 0:00:00

# %%
import os
import json
import time
import logging
from pathlib import Path
from dataclasses import dataclass, asdict
from functools import wraps

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.sparse import csr_matrix
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import StandardScaler, normalize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import joblib

# %matplotlib inline

logging.basicConfig(level=logging.INFO, format="%(asctime)s [%(levelname)s] %(message)s")
logger = logging.getLogger("recommender")

# %% [markdown]
# ### Configuration and Reproducibility

# %%
@dataclass
class RecConfig:
    # seed
    random_seed: int = 42
    top_k: int = 10

    # dataset
    n_users: int = 500
    n_tracks: int = 2000
    n_artists: int = 200
    n_genres: int = 15
    min_interactions: int = 10
    max_interactions: int = 80
    test_ratio: float = 0.2
    val_ratio: float = 0.1

    # model hparams
    svd_n_components: int = 50
    collab_weight: float = 0.6
    content_weight: float = 0.4

    # ranking
    popularity_weight: float = 0.05
    diversity_penalty: float = 0.1

    # paths
    data_dir: str = "./data"
    artifacts_dir: str = "./artifacts"

cfg = RecConfig()

AUDIO_FEATURES = [
    "danceability", "energy", "valence", "tempo",
    "acousticness", "instrumentalness", "loudness",
    "speechiness", "liveness",
]

GENRES = [
    "pop", "rock", "hip-hop", "r&b", "electronic", "jazz", "classical",
    "country", "latin", "indie", "metal", "folk", "blues", "reggae", "soul",
]

GENRE_FEATURE_PROFILES = {
    "pop":        {"danceability": 0.70, "energy": 0.65, "valence": 0.60, "tempo": 120, "acousticness": 0.15, "instrumentalness": 0.02, "loudness": -5.5, "speechiness": 0.05, "liveness": 0.12},
    "rock":       {"danceability": 0.50, "energy": 0.80, "valence": 0.45, "tempo": 130, "acousticness": 0.10, "instrumentalness": 0.05, "loudness": -4.5, "speechiness": 0.04, "liveness": 0.18},
    "hip-hop":    {"danceability": 0.78, "energy": 0.65, "valence": 0.50, "tempo": 100, "acousticness": 0.10, "instrumentalness": 0.01, "loudness": -6.0, "speechiness": 0.20, "liveness": 0.13},
    "r&b":        {"danceability": 0.68, "energy": 0.55, "valence": 0.55, "tempo": 105, "acousticness": 0.25, "instrumentalness": 0.02, "loudness": -7.0, "speechiness": 0.08, "liveness": 0.11},
    "electronic": {"danceability": 0.75, "energy": 0.80, "valence": 0.45, "tempo": 128, "acousticness": 0.05, "instrumentalness": 0.40, "loudness": -5.0, "speechiness": 0.06, "liveness": 0.15},
    "jazz":       {"danceability": 0.50, "energy": 0.40, "valence": 0.50, "tempo": 115, "acousticness": 0.60, "instrumentalness": 0.30, "loudness": -10.0, "speechiness": 0.04, "liveness": 0.20},
    "classical":  {"danceability": 0.25, "energy": 0.25, "valence": 0.35, "tempo": 100, "acousticness": 0.90, "instrumentalness": 0.85, "loudness": -18.0, "speechiness": 0.03, "liveness": 0.10},
    "country":    {"danceability": 0.55, "energy": 0.60, "valence": 0.65, "tempo": 125, "acousticness": 0.35, "instrumentalness": 0.02, "loudness": -6.5, "speechiness": 0.04, "liveness": 0.15},
    "latin":      {"danceability": 0.80, "energy": 0.70, "valence": 0.70, "tempo": 110, "acousticness": 0.20, "instrumentalness": 0.03, "loudness": -5.5, "speechiness": 0.07, "liveness": 0.14},
    "indie":      {"danceability": 0.55, "energy": 0.55, "valence": 0.50, "tempo": 118, "acousticness": 0.30, "instrumentalness": 0.10, "loudness": -8.0, "speechiness": 0.04, "liveness": 0.13},
    "metal":      {"danceability": 0.35, "energy": 0.92, "valence": 0.30, "tempo": 140, "acousticness": 0.02, "instrumentalness": 0.10, "loudness": -3.5, "speechiness": 0.06, "liveness": 0.20},
    "folk":       {"danceability": 0.45, "energy": 0.35, "valence": 0.55, "tempo": 110, "acousticness": 0.70, "instrumentalness": 0.05, "loudness": -11.0, "speechiness": 0.04, "liveness": 0.12},
    "blues":      {"danceability": 0.50, "energy": 0.50, "valence": 0.40, "tempo": 105, "acousticness": 0.50, "instrumentalness": 0.08, "loudness": -9.0, "speechiness": 0.04, "liveness": 0.18},
    "reggae":     {"danceability": 0.72, "energy": 0.55, "valence": 0.70, "tempo": 90, "acousticness": 0.30, "instrumentalness": 0.05, "loudness": -8.5, "speechiness": 0.05, "liveness": 0.14},
    "soul":       {"danceability": 0.62, "energy": 0.55, "valence": 0.60, "tempo": 108, "acousticness": 0.35, "instrumentalness": 0.03, "loudness": -7.5, "speechiness": 0.05, "liveness": 0.13},
}

for d in ["data/raw", "data/processed", "artifacts/models", "artifacts/metrics", "artifacts/figures"]:
    Path(d).mkdir(parents=True, exist_ok=True)

print(asdict(cfg))
# Out:
# {'random_seed': 42, 'top_k': 10, 'n_users': 500, 'n_tracks': 2000, 'n_artists': 200, 'n_genres': 15, 'min_interactions': 10, 'max_interactions': 80, 'test_ratio': 0.2, 'val_ratio': 0.1, 'svd_n_components': 50, 'collab_weight': 0.6, 'content_weight': 0.4, 'popularity_weight': 0.05, 'diversity_penalty': 0.1, 'data_dir': './data', 'artifacts_dir': './artifacts'}

# %%
def set_seed(seed=42):
    np.random.seed(seed)

set_seed(cfg.random_seed)

def save_artifact(obj, path):
    path = Path(path)
    path.parent.mkdir(parents=True, exist_ok=True)
    joblib.dump(obj, path)
    logger.info(f"Saved: {path}")

def load_artifact(path):
    return joblib.load(path)

def save_json(data, path):
    path = Path(path)
    path.parent.mkdir(parents=True, exist_ok=True)
    with open(path, "w") as f:
        json.dump(data, f, indent=2, default=str)

print(f"Seed set to {cfg.random_seed}")
# Out:
# Seed set to 42

# %% [markdown]
# ### Data Collection via Spotify API
#
# Real tracks fetched from the Spotify Web API across 15 genre-based playlists, with audio features retrieved per track. User interactions are synthetically generated over the real catalog — users get 1-3 preferred genres for collaborative signal, and play counts follow a power-law.

# %%
import os
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

logger = logging.getLogger("recommender")


def build_spotify_client():
    # read credentials from environment first, then fall back to notebook values
    client_id = os.getenv("SPOTIPY_CLIENT_ID", "")
    client_secret = os.getenv("SPOTIPY_CLIENT_SECRET", "")

    if not client_id or not client_secret:
        raise RuntimeError(
            "missing spotify credentials. set SPOTIPY_CLIENT_ID and SPOTIPY_CLIENT_SECRET."
        )

    return spotipy.Spotify(
        auth_manager=SpotifyClientCredentials(
            client_id=client_id,
            client_secret=client_secret,
        ),
        requests_timeout=10,
        retries=3,
    )


def _extract_track_row(track, genre):
    if not track:
        return None
    if not track.get("id"):
        return None
    if not track.get("artists"):
        return None

    artist = track["artists"][0]
    rd = (track.get("album") or {}).get("release_date", "2020")

    try:
        release_year = int(str(rd)[:4])
    except (ValueError, TypeError):
        release_year = 2020

    return {
        "track_id": track["id"],
        "track_name": track.get("name", ""),
        "artist_id": artist.get("id"),
        "artist_name": artist.get("name", ""),
        "genre": genre,
        "popularity": track.get("popularity", 50),
        "duration_ms": track.get("duration_ms", 200000),
        "release_year": release_year,
    }

def _search_tracks_for_genre(sp, genre, target_count):
    collected = {}
    offsets = [0, 10, 20, 30, 40]

    queries = [
        f'genre:"{genre}"',
        genre,
    ]

    for query in queries:
        for offset in offsets:
            try:
                resp = sp.search(
                    q=query,
                    type="track",
                    limit=10,
                    offset=offset,
                    market="US",
                )
            except Exception as e:
                logger.warning(f"track search failed for {genre} with query {query}: {e}")
                continue

            items = resp.get("tracks", {}).get("items", [])

            for track in items:
                row = _extract_track_row(track, genre)
                if row is None:
                    continue
                if row["track_id"] in collected:
                    continue

                collected[row["track_id"]] = row

                if len(collected) >= target_count:
                    return collected

            time.sleep(0.05)

    return collected


def fetch_spotify_tracks(rng, sp, cfg, GENRES, AUDIO_FEATURES, GENRE_FEATURE_PROFILES):
    # fetch real tracks from spotify using track search instead of playlist reads
    all_tracks = {}
    target_per_genre = cfg.n_tracks // len(GENRES) + 20

    expected_columns = [
        "track_id",
        "track_name",
        "artist_id",
        "artist_name",
        "genre",
        "popularity",
        "duration_ms",
        "release_year",
        *AUDIO_FEATURES,
    ]

    for genre in GENRES:
        try:
            collected = _search_tracks_for_genre(sp, genre, target_per_genre)
        except Exception as e:
            logger.warning(f"genre fetch failed for {genre}: {e}")
            collected = {}

        fresh_rows = 0
        for tid, row in collected.items():
            if tid not in all_tracks:
                all_tracks[tid] = row
                fresh_rows += 1

        print(f"{genre}: {fresh_rows} tracks")

    print(f"\ntotal unique tracks collected: {len(all_tracks)}")

    if not all_tracks:
        return pd.DataFrame(columns=expected_columns)

    # fetch audio features in batches
    track_ids_list = list(all_tracks.keys())
    features_ok = 0
    features_fail = 0

    for i in range(0, len(track_ids_list), 100):
        batch = track_ids_list[i:i + 100]

        try:
            feats = sp.audio_features(batch)

            for tid, feat in zip(batch, feats):
                if feat is not None:
                    for af in AUDIO_FEATURES:
                        all_tracks[tid][af] = feat.get(af, 0.0)
                    features_ok += 1
                else:
                    features_fail += 1

        except Exception as e:
            logger.warning(f"audio features batch error: {e}")
            features_fail += len(batch)

        time.sleep(0.05)

    print(f"audio features: {features_ok} fetched, {features_fail} missing")

    # fill missing audio features with fallback values
    for tid in all_tracks:
        if AUDIO_FEATURES[0] not in all_tracks[tid]:
            prof = GENRE_FEATURE_PROFILES[all_tracks[tid]["genre"]]

            for af in AUDIO_FEATURES:
                base = prof[af]

                if af == "tempo":
                    val = float(np.clip(base + rng.normal(0, 15), 50, 220))
                elif af == "loudness":
                    val = float(np.clip(base + rng.normal(0, 2), -30, 0))
                else:
                    val = float(np.clip(base + rng.normal(0, 0.08), 0, 1))

                all_tracks[tid][af] = val

    tracks_df = pd.DataFrame(list(all_tracks.values()))

    for col in expected_columns:
        if col not in tracks_df.columns:
            tracks_df[col] = np.nan

    # drop duplicates just in case the same track appears in multiple genre searches
    tracks_df = tracks_df.drop_duplicates(subset=["track_id"]).reset_index(drop=True)

    return tracks_df[expected_columns]


def generate_interactions(rng, tracks_df, cfg, GENRES):
    if tracks_df.empty or "track_id" not in tracks_df.columns:
        raise RuntimeError(
            "tracks dataframe is empty. spotify fetch likely failed due to authentication."
        )

    track_ids = tracks_df["track_id"].values
    track_genres = tracks_df["genre"].values
    pop_sum = max(1.0, tracks_df["popularity"].fillna(0).sum())
    track_pop = tracks_df["popularity"].fillna(0).values / pop_sum

    records = []
    base_ts = 1700000000

    for u in range(cfg.n_users):
        user_id = f"user_{u:04d}"
        preferred = set(rng.choice(GENRES, size=rng.integers(1, 4), replace=False))

        genre_mask = np.array([g in preferred for g in track_genres], dtype=float)
        weights = genre_mask * 5.0 + track_pop * 100 + 0.1
        weights /= weights.sum()

        n_available = len(track_ids)
        n_int = min(
            rng.integers(cfg.min_interactions, cfg.max_interactions + 1),
            n_available,
        )

        chosen = rng.choice(n_available, size=n_int, replace=False, p=weights)

        for idx in chosen:
            records.append(
                {
                    "user_id": user_id,
                    "track_id": track_ids[idx],
                    "play_count": min(int(rng.pareto(a=1.0) + 1), 50),
                    "timestamp": base_ts + int(rng.integers(0, 30000000)),
                }
            )

    return pd.DataFrame(records)


# main flow
rng = np.random.default_rng(cfg.random_seed)

tracks_path = Path("data/raw/tracks.csv")
interactions_path = Path("data/raw/interactions.csv")

# clear stale synthetic data
if tracks_path.exists():
    peek = pd.read_csv(tracks_path, nrows=1)
    if not peek.empty and "track_id" in peek.columns:
        if str(peek["track_id"].iloc[0]).startswith("track_"):
            tracks_path.unlink()
            if interactions_path.exists():
                interactions_path.unlink()
            print("cleared stale synthetic data and will refetch from spotify")

sp = build_spotify_client()

if tracks_path.exists() and interactions_path.exists():
    tracks_df = pd.read_csv(tracks_path)
    interactions_df = pd.read_csv(interactions_path)
    print("loaded cached spotify data from disk")
else:
    print("fetching tracks from spotify api")
    tracks_df = fetch_spotify_tracks(
        rng=rng,
        sp=sp,
        cfg=cfg,
        GENRES=GENRES,
        AUDIO_FEATURES=AUDIO_FEATURES,
        GENRE_FEATURE_PROFILES=GENRE_FEATURE_PROFILES,
    )

    if tracks_df.empty:
        raise RuntimeError(
            "no tracks were fetched from spotify. check your spotify credentials or token flow."
        )

    interactions_df = generate_interactions(rng, tracks_df, cfg, GENRES)

    tracks_path.parent.mkdir(parents=True, exist_ok=True)
    tracks_df.to_csv(tracks_path, index=False)
    interactions_df.to_csv(interactions_path, index=False)

    print(f"saved {len(tracks_df)} tracks and {len(interactions_df)} interactions")

print(f"tracks: {tracks_df.shape}, interactions: {interactions_df.shape}")
# Out:
# fetching tracks from spotify api
# pop: 78 tracks
# rock: 84 tracks
# hip-hop: 83 tracks
# r&b: 80 tracks
# electronic: 83 tracks
# jazz: 86 tracks
# classical: 79 tracks
# country: 79 tracks
# latin: 77 tracks
# indie: 66 tracks
# metal: 69 tracks
# folk: 77 tracks
# blues: 81 tracks
# reggae: 82 tracks
# ERROR:spotipy.client:HTTP Error for GET to https://api.spotify.com/v1/audio-features/?ids=3qhlB30KknSejmIvZZLjOD,6sGIMrtIzQjdzNndVxe397,68lbSrXDORS51pmyjZv712,5IMpnpD0tQVcqWlVIgtAtV,3B4cjvGlPvyBLNG3AzEgkZ,1DwscornXpj8fmOmYVlqZt,6Qyc6fS4DsZjB2mRW9DsQs,1qbmS6ep2hbBRaEZFpn7BX,7gtG45ieyQzKtNKobfLd49,0ofHAoxe9vBkTCp2UQIavz,03tqyYWC9Um2ZqU0ZN849H,53iuhJlwXhSER5J2IYYv1W,1rIKgCH4H52lrvDcz50hS8,5TRPicyLGbAF2LGBFbHGvO,0eaVIYo2zeOaGJeqZ5TwYz,6dOtVTDdiauQNBQEDOtlAB,55lijDD6OAjLFFUHU9tcDm,6LxSe8YmdPxy095Ux6znaQ,6f68Ac5tt5BQOpwr0BV9oN,3yWuTOYDztXjZxdE2cIRUa,0FIDCNYYjNvPVimz5icugS,3siwsiaEoU4Kuuc9WKMUy5,7KA4W4McWYRpgf0fWsJZWB,7qjZnBKE73H4Oxkopwulqe,1zi7xx7UVEFkmKfv06H8x0,68Dni7IE4VyPkTOH9mRWHr,0QPdjsMOUhwouq1NS3HwfQ,05od2qm2MTSKCHxy1GBp5W,312z6PZ8wwREck8613PkJk,3xClevycpBON8bkyxFbAna,2d8JP84HNLKhmd6IYOoupQ,3GCdLUSnKSMJhs4Tj6CV3s,0KKkJNfGyhkQ5aFogxQAPU,7ogpGbKc4Io6NCU6ydxXwZ,2rKkfc4VZ74FQDc1FF1Zo6,5mCPDVBb16L4XQwDdbRUpz,0d28khcov6AiegSCpG5TuT,2gam98EZKrF9XuOkU13ApN,7ghKr0pCYyPPyp7t1FH8k4,0WbMK4wrZ1wFSty9F7FCgu,3w3y8KPTfNeOKPiqUTakBh,20dAJsyno9ZoBLJtqgQnUI,2XHzzp1j4IfTNp1FTn7YFg,12bYYQaLqHliSXvRIYlq8G,4EWCNWgDS8707fNSZ1oaA5,2BwO5K8Q7EPAJSGze3AAh9,33iv3wnGMrrDugd7GBso1z,04emojnbYkrRmv5qtJcgVP,7gKxCvTDWwV9wBhdeBbr3l,0i4qKfuKJ3juUsEwnJAxk3,0kav2DxndmxlsiT3pqXZjG,6WzRpISELf3YglGAh7TXcG,3i8fIJNV0yuC4kXT3SkVBZ,028i7HBfp8uE5epmx5ieMA,6uFn47ACjqYkc0jADwEdj1,3702l19pLmnSRKFEzDnVeM,3j3SfV4hAcR4XjCvW393Gr,02sy7FAs8dkDNYsHp4Ul3f,6mSJEqkgiBMtqZSXSMvb4s,0QgwjxR1VchizzckKXwyBu,6z3HAUZpAyJ0ctsbAwAiw3,6EDO9iiTtwNv6waLwa1UUq,3Jv1XgMPVjdN5xGfnRJ20s,65m7WOTu8fMBFDd1r25VPk,0wzYHglk05SfNFN1aTRTlA,19UUPNx5jccGgQ2GCIZkww,7vGRXiYWFk6NjUnsNjQJQd,5zd9TgduWbfFXwgnm3K3Rz,26Fx8UbsC0BV4J1CdtuLAy,5l0uFjA731wPYH8CkR7K1Y,4GssB27iJeqmfGxS94Tfij,4xVmPboqdKG78mkqZ0sn1m,25G8NNFBnjXgWCGtyPa1Ax,3wn8nOygkHLUQ9dlXM1rKW,0So2sgVa8aJiARPl2P29u2,16PAC7NLpbryofiPTlqTFK,6WiZiKdPGXE73gjN2atqoS,57Pk2GU0ABFYBbbcgYxqki,70LcF31zb1H0PyJoS1Sx1r,6K4t31amVTZDgR3sKmwUJJ,003vvx7Niy0yvhvHt4a68B,5UWwZ5lm5PKu6eKsHAGxOk,1G391cbiT3v3Cywg8T7DM1,5e9TFTbltYBg2xThimr0rU,5ihS6UUlyQAfmp48eSkxuQ,5ghIJDpPoe3CfHMGu71E6T,1mea3bSkSGXuIRvnydlB5b,2SaWT781xr3hHLdbVt5DB7,4P5KoWXOxwuobLmHXLMobV,1O9D7P7Z1wMJXW19zTXrXi,60a0Rd6pjrkxjPbaKzXjfq,0COqiPhxzoWICwFCS4eZcp,0gEyKnHvgkrkBM6fbeHdwK,3d9DChrdc6BOeFsbrZ3Is0,3ZOEytgrvLwQaqXreDs2Jx,2fuYa3Lx06QQJAm0MjztKr,56sk7jBpZV0CD31G9hEU3b,40riOy7x9W7GXjyGp4pjAv,3VqHuw0wFlIHcIPWkhIbdQ,3agtg0x11wPvLIWkYR39nZ with Params: {} returned 403 due to None
# WARNING:recommender:audio features batch error: http status: 403, code: -1 - https://api.spotify.com/v1/audio-features/?ids=3qhlB30KknSejmIvZZLjOD,6sGIMrtIzQjdzNndVxe397,68lbSrXDORS51pmyjZv712,5IMpnpD0tQVcqWlVIgtAtV,3B4cjvGlPvyBLNG3AzEgkZ,1DwscornXpj8fmOmYVlqZt,6Qyc6fS4DsZjB2mRW9DsQs,1qbmS6ep2hbBRaEZFpn7BX,7gtG45ieyQzKtNKobfLd49,0ofHAoxe9vBkTCp2UQIavz,03tqyYWC9Um2ZqU0ZN849H,53iuhJlwXhSER5J2IYYv1W,1rIKgCH4H52lrvDcz50hS8,5TRPicyLGbAF2LGBFbHGvO,0eaVIYo2zeOaGJeqZ5TwYz,6dOtVTDdiauQNBQEDOtlAB,55lijDD6OAjLFFUHU9tcDm,6LxSe8YmdPxy095Ux6znaQ,6f68Ac5tt5BQOpwr0BV9oN,3yWuTOYDztXjZxdE2cIRUa,0FIDCNYYjNvPVimz5icugS,3siwsiaEoU4Kuuc9WKMUy5,7KA4W4McWYRpgf0fWsJZWB,7qjZnBKE73H4Oxkopwulqe,1zi7xx7UVEFkmKfv06H8x0,68Dni7IE4VyPkTOH9mRWHr,0QPdjsMOUhwouq1NS3HwfQ,05od2qm2MTSKCHxy1GBp5W,312z6PZ8wwREck8613PkJk,3xClevycpBON8bkyxFbAna,2d8JP84HNLKhmd6IYOoupQ,3GCdLUSnKSMJhs4Tj6CV3s,0KKkJNfGyhkQ5aFogxQAPU,7ogpGbKc4Io6NCU6ydxXwZ,2rKkfc4VZ74FQDc1FF1Zo6,5mCPDVBb16L4XQwDdbRUpz,0d28khcov6AiegSCpG5TuT,2gam98EZKrF9XuOkU13ApN,7ghKr0pCYyPPyp7t1FH8k4,0WbMK4wrZ1wFSty9F7FCgu,3w3y8KPTfNeOKPiqUTakBh,20dAJsyno9ZoBLJtqgQnUI,2XHzzp1j4IfTNp1FTn7YFg,12bYYQaLqHliSXvRIYlq8G,4EWCNWgDS8707fNSZ1oaA5,2BwO5K8Q7EPAJSGze3AAh9,33iv3wnGMrrDugd7GBso1z,04emojnbYkrRmv5qtJcgVP,7gKxCvTDWwV9wBhdeBbr3l,0i4qKfuKJ3juUsEwnJAxk3,0kav2DxndmxlsiT3pqXZjG,6WzRpISELf3YglGAh7TXcG,3i8fIJNV0yuC4kXT3SkVBZ,028i7HBfp8uE5epmx5ieMA,6uFn47ACjqYkc0jADwEdj1,3702l19pLmnSRKFEzDnVeM,3j3SfV4hAcR4XjCvW393Gr,02sy7FAs8dkDNYsHp4Ul3f,6mSJEqkgiBMtqZSXSMvb4s,0QgwjxR1VchizzckKXwyBu,6z3HAUZpAyJ0ctsbAwAiw3,6EDO9iiTtwNv6waLwa1UUq,3Jv1XgMPVjdN5xGfnRJ20s,65m7WOTu8fMBFDd1r25VPk,0wzYHglk05SfNFN1aTRTlA,19UUPNx5jccGgQ2GCIZkww,7vGRXiYWFk6NjUnsNjQJQd,5zd9TgduWbfFXwgnm3K3Rz,26Fx8UbsC0BV4J1CdtuLAy,5l0uFjA731wPYH8CkR7K1Y,4GssB27iJeqmfGxS94Tfij,4xVmPboqdKG78mkqZ0sn1m,25G8NNFBnjXgWCGtyPa1Ax,3wn8nOygkHLUQ9dlXM1rKW,0So2sgVa8aJiARPl2P29u2,16PAC7NLpbryofiPTlqTFK,6WiZiKdPGXE73gjN2atqoS,57Pk2GU0ABFYBbbcgYxqki,70LcF31zb1H0PyJoS1Sx1r,6K4t31amVTZDgR3sKmwUJJ,003vvx7Niy0yvhvHt4a68B,5UWwZ5lm5PKu6eKsHAGxOk,1G391cbiT3v3Cywg8T7DM1,5e9TFTbltYBg2xThimr0rU,5ihS6UUlyQAfmp48eSkxuQ,5ghIJDpPoe3CfHMGu71E6T,1mea3bSkSGXuIRvnydlB5b,2SaWT781xr3hHLdbVt5DB7,4P5KoWXOxwuobLmHXLMobV,1O9D7P7Z1wMJXW19zTXrXi,60a0Rd6pjrkxjPbaKzXjfq,0COqiPhxzoWICwFCS4eZcp,0gEyKnHvgkrkBM6fbeHdwK,3d9DChrdc6BOeFsbrZ3Is0,3ZOEytgrvLwQaqXreDs2Jx,2fuYa3Lx06QQJAm0MjztKr,56sk7jBpZV0CD31G9hEU3b,40riOy7x9W7GXjyGp4pjAv,3VqHuw0wFlIHcIPWkhIbdQ,3agtg0x11wPvLIWkYR39nZ:
#  None, reason: None
# ERROR:spotipy.client:HTTP Error for GET to https://api.spotify.com/v1/audio-features/?ids=2nLtzopw4rPReszdYBJU6h,0ntQJM78wzOLVeCUAW7Y45,5hM5arv9KDbCHS0k9uqwjr,2LawezPeJhN4AWuSB0GtAU,2hKdd3qO7cWr2Jo0Bcs0MA,57bgtoPSgt236HzfBOd8kj,7snQQk1zcKl8gZ92AnueZW,2374M0fQpWi3dLnB54qaLX,0TlcczkVTGpinpkGJpT81L,1158ckiB5S4cpsdYHDB9IF,2DlHlPMa4M17kufBvI2lEN,7aQjPecQdIuNd1sz3KCDhD,6PwjJ58I4t7Mae9xfZ9l9v,1nLnpLXvl68RZCSjfkyiaa,254bXAqt3zP6P50BdQvEsq,7w87IxuO7BDcJ3YUqCyMTT,79IgD1wf3xltQdDK3l5Why,2iUmqdfGZcHIhS3b9E9EWq,51c94ac31swyDQj9B3Lzs3,54eZmuggBFJbV7k248bTTt,20I8RduZC2PWMWTDCZuuAN,4Yf5bqU3NK4kNOypcrLYwU,4yugZvBYaoREkJKtbG08Qr,1yjY7rpaAQvKwpdUliHx0d,0M955bMOoilikPXwKLYpoi,0e7ipj03S05BNilyu5bRzt,7K8XoQXZBffc4xG2xIQHMO,1AWQoqb9bSvzTjaLralEkT,45sDIKapDyxPl307QpEAwl,1TE8AAk9koG0UJco6ZAUfx,6n9yCXvLhnYMgJIiIcMu7D,7oOOI85fVQvVnK5ynNMdW7,3gdewACMIVMEWVbyb8O9sY,1esmJ8t2PRbYt2yMx2aSEW,56KqaFSGTb7ifpt16t5Y1N,3fvY2U1AzW0diYF0hnBbKt,7ytR5pFWmSjzHJIeQkgog4,2Q5wSOwq6BDSu7sSVMNrtT,05tlUh0E6IFks9sCQguQKN,6KN9atd3DRhmSRWeCSKkkL,7iXYRR70wewzVYzWScm99j,4GF00uRxC4ECrxNEbnapqf,5QSiHPOYNCmpbwwMQyOGA6,6YOfGIE6iFxC7G8OlGGvzW,2hrUO4drrO63i7FYbCLBl2,4jCKLCyhHjrzz6be6NDhrd,58XWGx7KNNkKneHdprcprX,5nt46rgPQDwHJTJCitmcAt,4FlYcJnfkeBpowEHJ72Bmt,65ZihkVQO3KqPj7ZKxmcev,6dBUzqjtbnIa1TwYbyw5CM,1Lhwn4PqeGpM4LTVUowW76,7sdHMJvhKib3ReVPsZFbrf,2XHjFJVXYlEzoDvN82h8s5,1ne9wOtDF2jM6Cm8WBkaER,58ge6dfP91o9oXMzq3XkIS,6m5cyVx8qLqu69MFiBVnMI,0szij2qJqCH1PyrPfZcpi0,63gcHyuhAC8G2C0bVQUOJI,190l7oYBQe6JBsWPJM2uNN,2AMHDHBuhSvcEhbv5IVSB1,1ITQbrueGLl581a25XXm9c,2ISgvKPXrN0A0C4f7LysVb,0QzlhXzvy8ee3qBiTwjIHO,1hfV3SxJM4tpgjacZOfhaP,4tJBrv2TdeTRfoyGy1cEfZ,060EI1R20v7aE2kYoJzB11,0p777EKlSlrZXh79skdy61,0raMNT7W06U1TFn3QKxAgv,130dK37MesUPTn9bDc3cIZ,4jeBdUe4WKKlvZLVfDDmRp,569bNfozSnwmwvpS562wdk,4uNEPjCkIh8SFpKR32mmS7,1eKr13v2h5zuN46WnWoIrp,37k843ONsHa8FbxUqzYpoj,572mCZAcruQ6J5E1aZWG8u,0dg6p4CBNYSDtTBfTwElsY,4SwMQpT8mlN9DkJvKnguZ6,3cwwzUODsjR8tcwPj6fzk9,1GpLGzIClAhaduqV264A5k,6QosMDyk6THOARKlOQMpgS,20sALlU1jpMbJYuehimFTy,5mg0tcSdJdF34bSgdpbsSc,5fF5WMOMb0nwa8D7PfEZmm,1n34o0crw0nLCCnhDGg3I0,4QZxHF3UQtrSXWsVfM3xkz,3wwsDgaAZDrhjpMG1pu9sC,19cNRbcf2O6J5XsjuZSjDu,4VQngYLoPOzIhvi6KTceRW,58iNg8z3O92ymO1L0tuc39,3HNGCBYB3nGDecaQYEiYMo,62zs9jqYOvTM7Hc1KkIcgb,1bCWcxzK5epiZgqZDKoI4H,0yEURdneBMVdTnumc4aL1M,7GglkTmuE1fof7Wfva9gL4,4oyE6ZVh36A39iJCxkXnx1,1zAXE1hXoBLYQvzExszOB5,7t67OQifQsnv33BWHAtnQi,11y4KX1UlXYFxRFdqkpH93,6ry9yWm4AnSqB2hphCHGxv with Params: {} returned 403 due to None
# WARNING:recommender:audio features batch error: http status: 403, code: -1 - https://api.spotify.com/v1/audio-features/?ids=2nLtzopw4rPReszdYBJU6h,0ntQJM78wzOLVeCUAW7Y45,5hM5arv9KDbCHS0k9uqwjr,2LawezPeJhN4AWuSB0GtAU,2hKdd3qO7cWr2Jo0Bcs0MA,57bgtoPSgt236HzfBOd8kj,7snQQk1zcKl8gZ92AnueZW,2374M0fQpWi3dLnB54qaLX,0TlcczkVTGpinpkGJpT81L,1158ckiB5S4cpsdYHDB9IF,2DlHlPMa4M17kufBvI2lEN,7aQjPecQdIuNd1sz3KCDhD,6PwjJ58I4t7Mae9xfZ9l9v,1nLnpLXvl68RZCSjfkyiaa,254bXAqt3zP6P50BdQvEsq,7w87IxuO7BDcJ3YUqCyMTT,79IgD1wf3xltQdDK3l5Why,2iUmqdfGZcHIhS3b9E9EWq,51c94ac31swyDQj9B3Lzs3,54eZmuggBFJbV7k248bTTt,20I8RduZC2PWMWTDCZuuAN,4Yf5bqU3NK4kNOypcrLYwU,4yugZvBYaoREkJKtbG08Qr,1yjY7rpaAQvKwpdUliHx0d,0M955bMOoilikPXwKLYpoi,0e7ipj03S05BNilyu5bRzt,7K8XoQXZBffc4xG2xIQHMO,1AWQoqb9bSvzTjaLralEkT,45sDIKapDyxPl307QpEAwl,1TE8AAk9koG0UJco6ZAUfx,6n9yCXvLhnYMgJIiIcMu7D,7oOOI85fVQvVnK5ynNMdW7,3gdewACMIVMEWVbyb8O9sY,1esmJ8t2PRbYt2yMx2aSEW,56KqaFSGTb7ifpt16t5Y1N,3fvY2U1AzW0diYF0hnBbKt,7ytR5pFWmSjzHJIeQkgog4,2Q5wSOwq6BDSu7sSVMNrtT,05tlUh0E6IFks9sCQguQKN,6KN9atd3DRhmSRWeCSKkkL,7iXYRR70wewzVYzWScm99j,4GF00uRxC4ECrxNEbnapqf,5QSiHPOYNCmpbwwMQyOGA6,6YOfGIE6iFxC7G8OlGGvzW,2hrUO4drrO63i7FYbCLBl2,4jCKLCyhHjrzz6be6NDhrd,58XWGx7KNNkKneHdprcprX,5nt46rgPQDwHJTJCitmcAt,4FlYcJnfkeBpowEHJ72Bmt,65ZihkVQO3KqPj7ZKxmcev,6dBUzqjtbnIa1TwYbyw5CM,1Lhwn4PqeGpM4LTVUowW76,7sdHMJvhKib3ReVPsZFbrf,2XHjFJVXYlEzoDvN82h8s5,1ne9wOtDF2jM6Cm8WBkaER,58ge6dfP91o9oXMzq3XkIS,6m5cyVx8qLqu69MFiBVnMI,0szij2qJqCH1PyrPfZcpi0,63gcHyuhAC8G2C0bVQUOJI,190l7oYBQe6JBsWPJM2uNN,2AMHDHBuhSvcEhbv5IVSB1,1ITQbrueGLl581a25XXm9c,2ISgvKPXrN0A0C4f7LysVb,0QzlhXzvy8ee3qBiTwjIHO,1hfV3SxJM4tpgjacZOfhaP,4tJBrv2TdeTRfoyGy1cEfZ,060EI1R20v7aE2kYoJzB11,0p777EKlSlrZXh79skdy61,0raMNT7W06U1TFn3QKxAgv,130dK37MesUPTn9bDc3cIZ,4jeBdUe4WKKlvZLVfDDmRp,569bNfozSnwmwvpS562wdk,4uNEPjCkIh8SFpKR32mmS7,1eKr13v2h5zuN46WnWoIrp,37k843ONsHa8FbxUqzYpoj,572mCZAcruQ6J5E1aZWG8u,0dg6p4CBNYSDtTBfTwElsY,4SwMQpT8mlN9DkJvKnguZ6,3cwwzUODsjR8tcwPj6fzk9,1GpLGzIClAhaduqV264A5k,6QosMDyk6THOARKlOQMpgS,20sALlU1jpMbJYuehimFTy,5mg0tcSdJdF34bSgdpbsSc,5fF5WMOMb0nwa8D7PfEZmm,1n34o0crw0nLCCnhDGg3I0,4QZxHF3UQtrSXWsVfM3xkz,3wwsDgaAZDrhjpMG1pu9sC,19cNRbcf2O6J5XsjuZSjDu,4VQngYLoPOzIhvi6KTceRW,58iNg8z3O92ymO1L0tuc39,3HNGCBYB3nGDecaQYEiYMo,62zs9jqYOvTM7Hc1KkIcgb,1bCWcxzK5epiZgqZDKoI4H,0yEURdneBMVdTnumc4aL1M,7GglkTmuE1fof7Wfva9gL4,4oyE6ZVh36A39iJCxkXnx1,1zAXE1hXoBLYQvzExszOB5,7t67OQifQsnv33BWHAtnQi,11y4KX1UlXYFxRFdqkpH93,6ry9yWm4AnSqB2hphCHGxv:
#  None, reason: None
# soul: 74 tracks
#
# total unique tracks collected: 1178
# ERROR:spotipy.client:HTTP Error for GET to https://api.spotify.com/v1/audio-features/?ids=2mUmxDwwX1juJRHLZfqyU0,3sMvFTSPAxLqhDQHODMVAj,0nDJXFx78PuWeijVo3JlZY,2lSPbyDsIbngfvObibVGe5,2XgaRrAYE0DSmsiC3zpVvR,2YpNfDOCFT0dkn5csoFSMr,5GtgPd2ubzEMfbryF4VRfZ,5sIG2Jsyw1JfeNVtl2MAwl,28pD6XzeVXUtkI11oVAR4h,08eGAi7IvROcyXTcGpoEBW,4Bvjaq7xp9gUBgpZiAh1ez,17WYTOrHyqIgoRo9WTpAuf,0t5LNjml8LTuAPiEfD7zFN,2HoDr1yVksl19omOhc1zWy,0AqaHGj4lZpkjnokeLssTr,6EuhBJTydNXXtqBQ32lag5,1SyQ6t9RdRBK0QUCS6a797,3iWPD4snkNBcswQ4J6DNsq,0LByKylOLB93Lc19BjXMX2,5SkRLpaGtvYPhw02vZhQQ9,6AI3ezQ4o3HUoP6Dhudph3,5Cp75TUMrHF6c8xbhdligS,5iupE5tK6WVGkK2wXN7DlC,3GBrT6nOYfVwjz5NfR5EPW,46qyDt8oK4xUzKQM0YLMVV,4gQdwwPXSXnDkUh4jYqLoC,2wAJTrFhCnQyNSD3oUgTZO,4XSgaQfGgJ9FDCcvmOe404,3rHEMvr3C4wbL7vVs4LxxX,6N3oYlfZ2RPdjMYdHCRmFS,7iF9B5dbSOfEeznArGFHhn,2tudvzsrR56uom6smgOcSf,5MPPttjfGap2C6j6eKcO6J,5Lp1rg1qkv7CpFxs4198UG,4NTn0Yo8hTGW5tbBANBzfh,0twitsJEQTQXzkGwerCOtj,525yPO8r5J6kLostDxm3XK,6YTp4sUEi3oWNToQvOjke6,57Z6TJCTMACXxdrcwZ3Zvf,59nOXPmaKlBfGMDeOVGrIK,7rbECVPkY5UODxoOUVKZnA,3fDArTVS7UbDszl0Ky1nDx,5IdzhiIoGFVOkSKHyglOta,5FPihLzhH0bQ3tTco9VVdf,0rzSU1pxAyRyrrog5rKA2q,0JXXNGljqupsJaZsgSbMZV,4iZ4pt7kvcaH6Yo8UoZ4s2,0eAuGrXyGFYwur9ARUe7LJ,3Q4gttWQ6hxqWOa3tHoTNi,1Q7EgiMOuwDcB0PJC6AzON,0bxPRWprUVpQK0UFcddkrA,4k6Uh1HXdhtusDW5y8Gbvy,4jyyma8YdFC4S4llusSFRu,3pXF1nA74528Edde4of9CC,7tqhbajSfrz2F7E1Z75ASX,1eUGmzzvahJjOSWgDHuRlv,5Y35SjAfXjjG0sFQ3KOxmm,4PMqSO5qyjpvzhlLI5GnID,152lZdxL1OR0ZMW6KquMif,5Y77SQxEr1eiofPeUTPHxM,3a3dQOO19moXPeTt2PomoT,5rgrBsAFYMun6yhtnLKRPz,5VA4Ispp52EA1sOqzMz3Av,745H5CctFr12Mo7cqa1BMH,2uvE4L5ZsYKpv8hbK4TIOt,3NZJlJemX3mzjf56MqC5ML,3XgGQ1wjo5khvq2UImjyNF,2pg2TiYo9Rb8KeB5JjP7jS,43PuMrRfbyyuz4QpZ3oAwN,0GROiXm03OrMC5ltXLhGIu,3XVBdLihbNbxUwZosxcGuJ,2fXwCWkh6YG5zU1IyvQrbs,3koCCeSaVUyrRo3N2gHrd8,5WoaF1B5XIEnWfmb5NZikf,7uEFboafVLvROPYTqdMi0n,7eZXAeqqdLDrAp2MvrPzWn,4Ilen0VxPEsVRLpnePji8P,3aw9iWUQ3VrPQltgwvN9Xu,5c3luoCub1Z1Gg74NdNtuq,2Gyc6e2cLxA5hoX1NOvYnU,68vgtRHr7iZHpzGpon6Jlo,2OpBganfGk2GVdSlRdxzaX,040I32EKLxQrkuxQu1pqvT,4jnFqNWeJCeCRHc4HCdxfd,34ceTg8ChN5HjrqiIYCn9Q,3LmvfNUQtglbTrydsdIqFU,5ctk3VJoHoURSiwkCJn2bf,1K6oXSGIexEyNnv2cS6vKr,5PvVkf1Yuq3XyMqqjPiKPd,6m59VvDUi0UQsB2eZ9wVbH,74fQgHleHZ4V7Gm1XYcGkj,0q75NwOoFiARAVp4EXU4Bs,5QDGKcQLqOJvoiu8eScEaM,5oady7OSE7dH7LHiqmb3Cr,1JQ6Xm1JrvHfvAqhl5pwaA,70C5mlnBodNJqRYpQi7O9x,4JLyDROTzUGdqZKV9i4vIJ,58kHxwGFc3bWT9bVZ4lb6A,6I7rD5q2kN8eoZQ28IvuSh,0HzQIsuZfE1xy5MDG2Pi8r with Params: {} returned 403 due to None
# WARNING:recommender:audio features batch error: http status: 403, code: -1 - https://api.spotify.com/v1/audio-features/?ids=2mUmxDwwX1juJRHLZfqyU0,3sMvFTSPAxLqhDQHODMVAj,0nDJXFx78PuWeijVo3JlZY,2lSPbyDsIbngfvObibVGe5,2XgaRrAYE0DSmsiC3zpVvR,2YpNfDOCFT0dkn5csoFSMr,5GtgPd2ubzEMfbryF4VRfZ,5sIG2Jsyw1JfeNVtl2MAwl,28pD6XzeVXUtkI11oVAR4h,08eGAi7IvROcyXTcGpoEBW,4Bvjaq7xp9gUBgpZiAh1ez,17WYTOrHyqIgoRo9WTpAuf,0t5LNjml8LTuAPiEfD7zFN,2HoDr1yVksl19omOhc1zWy,0AqaHGj4lZpkjnokeLssTr,6EuhBJTydNXXtqBQ32lag5,1SyQ6t9RdRBK0QUCS6a797,3iWPD4snkNBcswQ4J6DNsq,0LByKylOLB93Lc19BjXMX2,5SkRLpaGtvYPhw02vZhQQ9,6AI3ezQ4o3HUoP6Dhudph3,5Cp75TUMrHF6c8xbhdligS,5iupE5tK6WVGkK2wXN7DlC,3GBrT6nOYfVwjz5NfR5EPW,46qyDt8oK4xUzKQM0YLMVV,4gQdwwPXSXnDkUh4jYqLoC,2wAJTrFhCnQyNSD3oUgTZO,4XSgaQfGgJ9FDCcvmOe404,3rHEMvr3C4wbL7vVs4LxxX,6N3oYlfZ2RPdjMYdHCRmFS,7iF9B5dbSOfEeznArGFHhn,2tudvzsrR56uom6smgOcSf,5MPPttjfGap2C6j6eKcO6J,5Lp1rg1qkv7CpFxs4198UG,4NTn0Yo8hTGW5tbBANBzfh,0twitsJEQTQXzkGwerCOtj,525yPO8r5J6kLostDxm3XK,6YTp4sUEi3oWNToQvOjke6,57Z6TJCTMACXxdrcwZ3Zvf,59nOXPmaKlBfGMDeOVGrIK,7rbECVPkY5UODxoOUVKZnA,3fDArTVS7UbDszl0Ky1nDx,5IdzhiIoGFVOkSKHyglOta,5FPihLzhH0bQ3tTco9VVdf,0rzSU1pxAyRyrrog5rKA2q,0JXXNGljqupsJaZsgSbMZV,4iZ4pt7kvcaH6Yo8UoZ4s2,0eAuGrXyGFYwur9ARUe7LJ,3Q4gttWQ6hxqWOa3tHoTNi,1Q7EgiMOuwDcB0PJC6AzON,0bxPRWprUVpQK0UFcddkrA,4k6Uh1HXdhtusDW5y8Gbvy,4jyyma8YdFC4S4llusSFRu,3pXF1nA74528Edde4of9CC,7tqhbajSfrz2F7E1Z75ASX,1eUGmzzvahJjOSWgDHuRlv,5Y35SjAfXjjG0sFQ3KOxmm,4PMqSO5qyjpvzhlLI5GnID,152lZdxL1OR0ZMW6KquMif,5Y77SQxEr1eiofPeUTPHxM,3a3dQOO19moXPeTt2PomoT,5rgrBsAFYMun6yhtnLKRPz,5VA4Ispp52EA1sOqzMz3Av,745H5CctFr12Mo7cqa1BMH,2uvE4L5ZsYKpv8hbK4TIOt,3NZJlJemX3mzjf56MqC5ML,3XgGQ1wjo5khvq2UImjyNF,2pg2TiYo9Rb8KeB5JjP7jS,43PuMrRfbyyuz4QpZ3oAwN,0GROiXm03OrMC5ltXLhGIu,3XVBdLihbNbxUwZosxcGuJ,2fXwCWkh6YG5zU1IyvQrbs,3koCCeSaVUyrRo3N2gHrd8,5WoaF1B5XIEnWfmb5NZikf,7uEFboafVLvROPYTqdMi0n,7eZXAeqqdLDrAp2MvrPzWn,4Ilen0VxPEsVRLpnePji8P,3aw9iWUQ3VrPQltgwvN9Xu,5c3luoCub1Z1Gg74NdNtuq,2Gyc6e2cLxA5hoX1NOvYnU,68vgtRHr7iZHpzGpon6Jlo,2OpBganfGk2GVdSlRdxzaX,040I32EKLxQrkuxQu1pqvT,4jnFqNWeJCeCRHc4HCdxfd,34ceTg8ChN5HjrqiIYCn9Q,3LmvfNUQtglbTrydsdIqFU,5ctk3VJoHoURSiwkCJn2bf,1K6oXSGIexEyNnv2cS6vKr,5PvVkf1Yuq3XyMqqjPiKPd,6m59VvDUi0UQsB2eZ9wVbH,74fQgHleHZ4V7Gm1XYcGkj,0q75NwOoFiARAVp4EXU4Bs,5QDGKcQLqOJvoiu8eScEaM,5oady7OSE7dH7LHiqmb3Cr,1JQ6Xm1JrvHfvAqhl5pwaA,70C5mlnBodNJqRYpQi7O9x,4JLyDROTzUGdqZKV9i4vIJ,58kHxwGFc3bWT9bVZ4lb6A,6I7rD5q2kN8eoZQ28IvuSh,0HzQIsuZfE1xy5MDG2Pi8r:
#  None, reason: None
# ERROR:spotipy.client:HTTP Error for GET to https://api.spotify.com/v1/audio-features/?ids=5FTdV6CuA58OUFh4kOjQEk,3LtQtMTElsBhQQl1Oe2WVv,1KGi9sZVMeszgZOWivFpxs,4WFgvKVfEhb3IUAFGrutTR,0NgUHhfUiNaZ4H6NTGytox,2b5VxVsNoXJosLvDLnEQkq,589wbQoNO2boSl7vdZpSy1,0NM2ldvMzC8X5RHfgRghgb,3UDWZudwPWeraBReytHrdQ,2LPSMJ9qDV6db3xXmpuITl,60bO3aRWCp9MjbmULloA3w,6yRsDLeo8qszcOS2u11ZDn,3wVEaw5dNW3n2cCksllGQ0,2FGT4Tpk5M9qO2nBHpNE6R,16oudUlFkeGjYWrxwfB0nK,4mXHaZR1RuZktEFS6Wnlt3,1BEfoG77YaffonKczkp1LE,7Jla74vtCOUMve0rIyIYm7,58FubOShFKQO7DxHTHAayN,7yNf9YjeO5JXUE3JEBgnYc,2LlOeW5rVcvl3QcPNPcDus,2bHNiAlF4UK1TF7nWOgyKa,4FVABuHkos5ulUP6gin3Go,73v2KnGBqNkbq7PfQDxITP,7hbMVObu49Baf8IkGkcnsp,0lHAMNU8RGiIObScrsRgmP,1TfqLAPs4K3s2rJMoCokcS,1gihuPhrLraKYrJMAEONyc,60wwxj6Dd9NJlirf84wr2c,7MmG8p0F9N3C4AXdK6o6Eb,57kR5SniQIbsbVoIjjOUDa,6YUTL4dYpB9xZO5qExPf05,5p3SJ3CYqrmFbboAtfNo5n,6LUGvXEAK8WxIBYK43uoTb,1xaTREM89RbIxkcjlpf4Uw,7vg9noSnFEyPfwLiaCW4vi,4uUG5RXrOk84mYEfFvj3cK,1lbNgoJ5iMrMluCyhI4OQP,6r7b1UHvO3fBZe7wBXWTaZ,4Pd6KvXa6DVEA5Wr41k9Dw,1eyzqe2QqGZUmfcPZtrIyt,2V65y3PX4DkRhy1djlxd9p,0DiWol3AO6WpXZgp0goxAV,5q0N5SaFhROG9UQiPukv9p,1FvDJ9KGxcqwv1utyPL3JZ,2Y0iGXY6m6immVb2ktbseM,5YJtMNWKe55yr49cyJgxva,0uXO2GrNiIb1xHT9LUdxZE,0g5EKLgdKvNlln7TNqBByK,7uv632EkfwYhXoqf8rhYrg,0kl6Ozan3fuUdCl6TlB15v,1V8eQfZ1zpcdA9ctIb6fY7,4o0LyB69tylqDG6eTGhmig,5XVjNRubJUW0iPhhSWpLCj,5mc6EyF1OIEOhAkD0Gg9Lc,2P4OICZRVAQcYAV2JReRfj,5UqCQaDshqbIk3pkhy4Pjg,1ElySIlHwm1HX7sUjAZZnp,07nH4ifBxUB4lZcsf44Brn,7MStpKz6w6a7Kq0QR7QTu0,2QtJA4gbwe1AcanB2p21aP,78nx0HDJIFD5xDq2L5420Z,24LS4lQShWyixJ0ZrJXfJ5,0OTO8ZF2YqFQVw9hnZylTd,6BrMEbPSSj55nQhkgf6DnE,5K9TkyWt2C4yWFwI2Npz48,4S1VYqwfkLit9mKVY3MXoo,2LKOHdMsL0K9KwcPRlJK2v,3sl4dcqSwxHVnLfqwF2jly,66hayvUbTotekKU3H4ta1f,46lFttIf5hnUZMGvjK0Wxo,5ObyGDxNWH0Uuuk3NvC5r8,6EMynpZ10GVcwVqiLZj6Ye,32VIrOsJmwvqRm4rWFBCsi,3pUz2qJe5nqZemi3hhIxMk,1RJY9Sgj963s3nQfF3VuR3,39cmB3ZoTOLwOTq7tMNqKa,6zyKrSyQWUqbIHAHQnCKry,4UtG2YGIpQIR9QFDXxJQFr,25dAjY6eOu4LTsBYfraOKA,1LjxxIT0LdC4HohMouVn5a,4GnZr9MZvLlOKj4k0wkYV5,0nrRP2bk19rLc0orkWPQk2,1oZw7eD88LKJR9A27jdIkH,6xGgDE7TSvGwhOKBdv9dMH,7mHr69kU0Wig5cw7PG8I0G,3S7Wn5DPIfUoJaGyQUtrV1,7DAXfp0cSOTnUjhxrbtSOi,6LljI9OX4JP1sSqY4m9Gti,3XhlW9B33kEA4N2rNBqL4q,5fUh73ihdzB2SaIftDD3EG,1cZcQDZzx940vWz9PFRY20,3Rdnhu0ZEaJBATbOedN4pp,3oTzvWsWa5v91cI5LsqhyE,3vk4V4vwotEvP16U1cM0HQ,5JVbvCHX10U2pLa5DEqGav,1i1fxkWeaMmKEB4T7zqbzK,4cYQD8YRxq88kpb4EC7Fb9,47t30Tl0EkQeiNbGFRANay,5vrbktcSGJgKaOc7epRDsY with Params: {} returned 403 due to None
# WARNING:recommender:audio features batch error: http status: 403, code: -1 - https://api.spotify.com/v1/audio-features/?ids=5FTdV6CuA58OUFh4kOjQEk,3LtQtMTElsBhQQl1Oe2WVv,1KGi9sZVMeszgZOWivFpxs,4WFgvKVfEhb3IUAFGrutTR,0NgUHhfUiNaZ4H6NTGytox,2b5VxVsNoXJosLvDLnEQkq,589wbQoNO2boSl7vdZpSy1,0NM2ldvMzC8X5RHfgRghgb,3UDWZudwPWeraBReytHrdQ,2LPSMJ9qDV6db3xXmpuITl,60bO3aRWCp9MjbmULloA3w,6yRsDLeo8qszcOS2u11ZDn,3wVEaw5dNW3n2cCksllGQ0,2FGT4Tpk5M9qO2nBHpNE6R,16oudUlFkeGjYWrxwfB0nK,4mXHaZR1RuZktEFS6Wnlt3,1BEfoG77YaffonKczkp1LE,7Jla74vtCOUMve0rIyIYm7,58FubOShFKQO7DxHTHAayN,7yNf9YjeO5JXUE3JEBgnYc,2LlOeW5rVcvl3QcPNPcDus,2bHNiAlF4UK1TF7nWOgyKa,4FVABuHkos5ulUP6gin3Go,73v2KnGBqNkbq7PfQDxITP,7hbMVObu49Baf8IkGkcnsp,0lHAMNU8RGiIObScrsRgmP,1TfqLAPs4K3s2rJMoCokcS,1gihuPhrLraKYrJMAEONyc,60wwxj6Dd9NJlirf84wr2c,7MmG8p0F9N3C4AXdK6o6Eb,57kR5SniQIbsbVoIjjOUDa,6YUTL4dYpB9xZO5qExPf05,5p3SJ3CYqrmFbboAtfNo5n,6LUGvXEAK8WxIBYK43uoTb,1xaTREM89RbIxkcjlpf4Uw,7vg9noSnFEyPfwLiaCW4vi,4uUG5RXrOk84mYEfFvj3cK,1lbNgoJ5iMrMluCyhI4OQP,6r7b1UHvO3fBZe7wBXWTaZ,4Pd6KvXa6DVEA5Wr41k9Dw,1eyzqe2QqGZUmfcPZtrIyt,2V65y3PX4DkRhy1djlxd9p,0DiWol3AO6WpXZgp0goxAV,5q0N5SaFhROG9UQiPukv9p,1FvDJ9KGxcqwv1utyPL3JZ,2Y0iGXY6m6immVb2ktbseM,5YJtMNWKe55yr49cyJgxva,0uXO2GrNiIb1xHT9LUdxZE,0g5EKLgdKvNlln7TNqBByK,7uv632EkfwYhXoqf8rhYrg,0kl6Ozan3fuUdCl6TlB15v,1V8eQfZ1zpcdA9ctIb6fY7,4o0LyB69tylqDG6eTGhmig,5XVjNRubJUW0iPhhSWpLCj,5mc6EyF1OIEOhAkD0Gg9Lc,2P4OICZRVAQcYAV2JReRfj,5UqCQaDshqbIk3pkhy4Pjg,1ElySIlHwm1HX7sUjAZZnp,07nH4ifBxUB4lZcsf44Brn,7MStpKz6w6a7Kq0QR7QTu0,2QtJA4gbwe1AcanB2p21aP,78nx0HDJIFD5xDq2L5420Z,24LS4lQShWyixJ0ZrJXfJ5,0OTO8ZF2YqFQVw9hnZylTd,6BrMEbPSSj55nQhkgf6DnE,5K9TkyWt2C4yWFwI2Npz48,4S1VYqwfkLit9mKVY3MXoo,2LKOHdMsL0K9KwcPRlJK2v,3sl4dcqSwxHVnLfqwF2jly,66hayvUbTotekKU3H4ta1f,46lFttIf5hnUZMGvjK0Wxo,5ObyGDxNWH0Uuuk3NvC5r8,6EMynpZ10GVcwVqiLZj6Ye,32VIrOsJmwvqRm4rWFBCsi,3pUz2qJe5nqZemi3hhIxMk,1RJY9Sgj963s3nQfF3VuR3,39cmB3ZoTOLwOTq7tMNqKa,6zyKrSyQWUqbIHAHQnCKry,4UtG2YGIpQIR9QFDXxJQFr,25dAjY6eOu4LTsBYfraOKA,1LjxxIT0LdC4HohMouVn5a,4GnZr9MZvLlOKj4k0wkYV5,0nrRP2bk19rLc0orkWPQk2,1oZw7eD88LKJR9A27jdIkH,6xGgDE7TSvGwhOKBdv9dMH,7mHr69kU0Wig5cw7PG8I0G,3S7Wn5DPIfUoJaGyQUtrV1,7DAXfp0cSOTnUjhxrbtSOi,6LljI9OX4JP1sSqY4m9Gti,3XhlW9B33kEA4N2rNBqL4q,5fUh73ihdzB2SaIftDD3EG,1cZcQDZzx940vWz9PFRY20,3Rdnhu0ZEaJBATbOedN4pp,3oTzvWsWa5v91cI5LsqhyE,3vk4V4vwotEvP16U1cM0HQ,5JVbvCHX10U2pLa5DEqGav,1i1fxkWeaMmKEB4T7zqbzK,4cYQD8YRxq88kpb4EC7Fb9,47t30Tl0EkQeiNbGFRANay,5vrbktcSGJgKaOc7epRDsY:
#  None, reason: None
# ERROR:spotipy.client:HTTP Error for GET to https://api.spotify.com/v1/audio-features/?ids=1pxtVltVk25vv4YuwZFuMN,1WvPGcBaRNQ7dztD7Dmmqk,5uNkKCRiKHUciG6JBvWqCL,0ZBgGxQjcQBja6hVEnEbrU,0K5dMpBtt4W8n46f5tbhRi,0Z6fnBHUEUu1ik22d5Sa4U,6MyOUlquDXcAtkFre8ki2w,7GkHpXXRh7JJjnZzu4jSnf,6dWilYAxP2aJbTTt0UsatK,0UqHzMvRQnaOXEPKgFVhxN,0RRpMyf3DjSxBvwMYQVXt7,4nwjvcUjV7cexhwA40Bh5i,4F5ka6lx7RlUWGjzTIby5D,4KGGeE7RJsgLNZmnxGFlOj,08PdFBcXzpkn1cWNgmKqhn,1gjrb6iiP6KIrQnDBIqqDi,4UQDZlZhGUDoYMohwrY28v,47oS7xB31QQUyPCgHpM3VZ,5BBW0U4l8cmjYgzx6A0vkP,4QxDOjgpYtQDxxbWPuEJOy,7DEM0croHHjdj4ZmJa9O0h,2s4kfMyVXLtqTVf6ynDbf0,3dYY2sYUzBCLE9BLVHedjB,2SPbioo65CuUB3H0aW1ID5,24Q7aiqWzNr5qzpdp5S3ip,2DG20cnHcJch4H9pbL9w7r,5wL9bbT4NKoQ5aikuFCGvT,3Ci1aN2eXmaPEwdaTe968z,1bTAsAvDcQFJt1hSuxYKmj,7Hot0NPga1p3EeeU2nRcTO,19uTUk6QgqMrUx3oqtwfBB,2AD9ENIeGBDjNNqzynaoiK,6TYacOsNqTCnySdrfI2tuc,1MIaqQHwmB5RAFMBH1rN3W,7N3mP4CQRp2jNdXFKDdGln,6Qz3tsqLqEwH1Fha5giani,6Q3vUVKAyxQfk18HKLC6oo,6Ev0CSFpXv04LPgdrYFfFV,4goKkl6dus0ELGI3jmSup2,4oRTIaRB1g1MuerWYtWZXt,2zSSu88dL3lnXtMOW45NhD,4JNx8ydySvX2eMgnYUcuwM,3ggflHy7MWP2jNWZNcV4aU,28bAwLIUVQb34hhwy4qxOh,4jvdZ6sgCBJWTpNJU993XR,58gD6Ar46jH2u3Vn45SwMJ,79kRjRQKIDqkfKx3yDo49c,3OiDcN4f5491LuW16SauKI,1ko2lVN0vKGUl9zrU0qSlT,1YxQxV5sKZN1TgVpXl5MLA,4tyjNEHKos3lZPYAfTiMKH,4Y9Ge3i5r0vgFAZq653Yx3,5zHLswJplBXyPstFSSMIOH,648TTtYB0bH0P8Hfy0FmkL,5b7OgznPJJr1vHNYGyvxau,608wYP5XWenLz8cOSYjX7X,39fD0qvjgk8RarJnoBiDTx,2j4vJ8QuUGd0Jbk0znPgv3,5tp5lixxnFoKu6WAVBri75,0WZomj99qKEzipmSQIQktM,2JJ9z5cHcm1fXkp8lDVaQ2,3jbnpv6yDbZGruKmPFu54k,06SYfhYSo9iY3txHE6W9Dl,7hQJA50XrCWABAu5v6QZ4i,2rk0lCpO1vkKAQ6BC8bjUX,7AgMX97ljLm9BzszyyXEYZ,0pjCsB0XNSyqM9UazlTODC,6w4MlvpuxtbjGdL9YeTx89,4N6SmWg9M92xRwejuVBxwQ,4igIYHF3B5VBxEafHauVo3,2zMn261sjoitKZJehIMKPD,1D5PMly59volxN3IJMv9bt,0TrEMKiKV6JE7PyGkmm2VV,2gAGWaK4wvt2xrFUlR4mK8,1muuU1537td0NXq2cf6BNh,7fAhwIX8dBLJF2AaPE2Gu6,4fdftRy6Gon68yCvJzOtYo,7zXlffO8UaDImckPFY0Zth,1NsIh627OjaxehLQx8LibX,3ePfQO7BA5uOnz7SQJ8gtp,1kPBT8S2wJFNAyBMnGVZgL,0IxLXLJHEnYlTjek6A0moU,0dgdDB39uUoC8WICmTE2U8,180AbZduI6bYQIzwCHRwu9,64OJBvUoBussjz3u8hNg2m,55kOpqN4YZ3iklTGj42ZeL,15Csfc8bkcJRCT04OErRkP,6zEg4KEgz6RGhCPmDKplYf,4JsFiWQgbHAERpa7k6Plsc,2HuQ4dfi6TsqGMIrYSkuAD,3eQnyx0B0yMZslWaxztNfA,7g4Cd8Cti1eHrcTyDXPfYP,14RIOUO6Eb8NmwX8BeVMpm,7IRqIPi7qB4xkrswHvBZAN,612bl0KHzyyxEhPzuMqM6e,6pWlv50Lthad8jyd6f1TlC,2LTCVKCcbKQBoqofOkI0fB,3xtiXNDbSKxy20I7D6vFUg,5QYUNHT2dQwoNHorXznygN,1BncfTJAWxrsxyT9culBrj with Params: {} returned 403 due to None
# WARNING:recommender:audio features batch error: http status: 403, code: -1 - https://api.spotify.com/v1/audio-features/?ids=1pxtVltVk25vv4YuwZFuMN,1WvPGcBaRNQ7dztD7Dmmqk,5uNkKCRiKHUciG6JBvWqCL,0ZBgGxQjcQBja6hVEnEbrU,0K5dMpBtt4W8n46f5tbhRi,0Z6fnBHUEUu1ik22d5Sa4U,6MyOUlquDXcAtkFre8ki2w,7GkHpXXRh7JJjnZzu4jSnf,6dWilYAxP2aJbTTt0UsatK,0UqHzMvRQnaOXEPKgFVhxN,0RRpMyf3DjSxBvwMYQVXt7,4nwjvcUjV7cexhwA40Bh5i,4F5ka6lx7RlUWGjzTIby5D,4KGGeE7RJsgLNZmnxGFlOj,08PdFBcXzpkn1cWNgmKqhn,1gjrb6iiP6KIrQnDBIqqDi,4UQDZlZhGUDoYMohwrY28v,47oS7xB31QQUyPCgHpM3VZ,5BBW0U4l8cmjYgzx6A0vkP,4QxDOjgpYtQDxxbWPuEJOy,7DEM0croHHjdj4ZmJa9O0h,2s4kfMyVXLtqTVf6ynDbf0,3dYY2sYUzBCLE9BLVHedjB,2SPbioo65CuUB3H0aW1ID5,24Q7aiqWzNr5qzpdp5S3ip,2DG20cnHcJch4H9pbL9w7r,5wL9bbT4NKoQ5aikuFCGvT,3Ci1aN2eXmaPEwdaTe968z,1bTAsAvDcQFJt1hSuxYKmj,7Hot0NPga1p3EeeU2nRcTO,19uTUk6QgqMrUx3oqtwfBB,2AD9ENIeGBDjNNqzynaoiK,6TYacOsNqTCnySdrfI2tuc,1MIaqQHwmB5RAFMBH1rN3W,7N3mP4CQRp2jNdXFKDdGln,6Qz3tsqLqEwH1Fha5giani,6Q3vUVKAyxQfk18HKLC6oo,6Ev0CSFpXv04LPgdrYFfFV,4goKkl6dus0ELGI3jmSup2,4oRTIaRB1g1MuerWYtWZXt,2zSSu88dL3lnXtMOW45NhD,4JNx8ydySvX2eMgnYUcuwM,3ggflHy7MWP2jNWZNcV4aU,28bAwLIUVQb34hhwy4qxOh,4jvdZ6sgCBJWTpNJU993XR,58gD6Ar46jH2u3Vn45SwMJ,79kRjRQKIDqkfKx3yDo49c,3OiDcN4f5491LuW16SauKI,1ko2lVN0vKGUl9zrU0qSlT,1YxQxV5sKZN1TgVpXl5MLA,4tyjNEHKos3lZPYAfTiMKH,4Y9Ge3i5r0vgFAZq653Yx3,5zHLswJplBXyPstFSSMIOH,648TTtYB0bH0P8Hfy0FmkL,5b7OgznPJJr1vHNYGyvxau,608wYP5XWenLz8cOSYjX7X,39fD0qvjgk8RarJnoBiDTx,2j4vJ8QuUGd0Jbk0znPgv3,5tp5lixxnFoKu6WAVBri75,0WZomj99qKEzipmSQIQktM,2JJ9z5cHcm1fXkp8lDVaQ2,3jbnpv6yDbZGruKmPFu54k,06SYfhYSo9iY3txHE6W9Dl,7hQJA50XrCWABAu5v6QZ4i,2rk0lCpO1vkKAQ6BC8bjUX,7AgMX97ljLm9BzszyyXEYZ,0pjCsB0XNSyqM9UazlTODC,6w4MlvpuxtbjGdL9YeTx89,4N6SmWg9M92xRwejuVBxwQ,4igIYHF3B5VBxEafHauVo3,2zMn261sjoitKZJehIMKPD,1D5PMly59volxN3IJMv9bt,0TrEMKiKV6JE7PyGkmm2VV,2gAGWaK4wvt2xrFUlR4mK8,1muuU1537td0NXq2cf6BNh,7fAhwIX8dBLJF2AaPE2Gu6,4fdftRy6Gon68yCvJzOtYo,7zXlffO8UaDImckPFY0Zth,1NsIh627OjaxehLQx8LibX,3ePfQO7BA5uOnz7SQJ8gtp,1kPBT8S2wJFNAyBMnGVZgL,0IxLXLJHEnYlTjek6A0moU,0dgdDB39uUoC8WICmTE2U8,180AbZduI6bYQIzwCHRwu9,64OJBvUoBussjz3u8hNg2m,55kOpqN4YZ3iklTGj42ZeL,15Csfc8bkcJRCT04OErRkP,6zEg4KEgz6RGhCPmDKplYf,4JsFiWQgbHAERpa7k6Plsc,2HuQ4dfi6TsqGMIrYSkuAD,3eQnyx0B0yMZslWaxztNfA,7g4Cd8Cti1eHrcTyDXPfYP,14RIOUO6Eb8NmwX8BeVMpm,7IRqIPi7qB4xkrswHvBZAN,612bl0KHzyyxEhPzuMqM6e,6pWlv50Lthad8jyd6f1TlC,2LTCVKCcbKQBoqofOkI0fB,3xtiXNDbSKxy20I7D6vFUg,5QYUNHT2dQwoNHorXznygN,1BncfTJAWxrsxyT9culBrj:
#  None, reason: None
# ERROR:spotipy.client:HTTP Error for GET to https://api.spotify.com/v1/audio-features/?ids=2AX5E86cn9n2dgioZEjirI,1cmigB9I6IRpFqjIbzvSQB,5S8pvaRvZzLFvtbaJGxdp3,1AoLEGCko16VHdYsG2POwH,2xizRhme7pYeITbH1NLLGt,2agBDIr9MYDUducQPC1sFU,2NHHKv9F4mYLSMfMl0jayB,5NGtFXVpXSvwunEIGeviY3,4VnDmjYCZkyeqeb0NIKqdA,56oReVXIfUO9xkX7pHmEU0,3U8Fx7zNTQrctytkj6Gqgd,2LKMUX3iN0tQOvggbalydj,6K4uQfVY4NGXQXx9Gq8LQa,2hegfLKqobbWtYPg0Z31vm,3tW8IodDhbGqOzz4i24qjz,3weNRklVDqb4Rr5MhKBR3D,39uLYYZytVUwcjgeYLI409,2vCGb0Sr5ismOhXPliKLRW,3Dgmyz32dxvtxvUTPS0CUI,2SV6rrWHkmxOgV4FwrGxl5,0NqpLq9EZGy9HCK6xWpGep,4Rr3fUE84z8AjJshTRiCWt,5vh2NNTsI6A5pvc9GaYbj7,57udUUmrolC21iP6xtgNBU,5GpfyJrKHJI36jDKtQiyGN,3gS0VrWH2NyPGXYiFmcagd,3gFQOMoUwlR6aUZj81gCzu,7MJ8g0egEkhvGu44IamrDE,2MSgFefjK0T7Iwjvr3OKqV,5UreKbsH9dpfxDB2m6D3Ho,48i1p3R9l9f7zjcHPJysZZ,4XoxeBjlebxva3UpSBULCl,3HJImjLAcnltzIkexQIsJR,4fG5KccAJKYk1EguGbGKt0,7jYydzcZOWVkUFA2q0nQEz,67owhi2vdncwSNE4fEM5Lc,6pnlZLblzKIkPVIojZIplR,5Ic6SKZUhkNusxykGhP31p,7CGrAECnWxyKdSZg29AqoT,1OYjEkmuPByqreZK6IGZiD,62MPgke3glg54RhupICvV9,4hMPpspODHxVP4WbY2T7C1,1dxmixovg25mSp8bESrmMe,7dB6FOZU8mcnij2O9G53wO,1DfGPEHxTYeaJpiNA4xUb5,6XzyCjS2Z2zgGIAk1p5nKB,4DK3JpX2NkEMhCnltUEvUg,4b7FS62swyDhSMk7TBxL57,05wcENjdczP23mxt3qFihI,77oGPqxT7yDZ5OCRmR863C,3EYOJ48Et32uATr9ZmLnAo,4PGrQH5eUSlo8CxdUHRDx3,0g8zASF1mldclJswQ0IQYJ,2Gkwgols6E2yZmBMKeiSRI,0dN8P5k2OymyDJ6GPhIT0n,73QRUJwvitJp80FajryNkK,4DlGLD32K7shuL8ub067DL,6UjiABdNRhHLMWFvRDZSVD,3kfR3pry54a3QhQ1yWVIYN,4SPJDte2kZKgY1Dw2yzmkK,69oIQ9UUcVTopztpOdiwH2,2munHzvVYjZhAa4lj26wcR,37ruL0882SPad6hYhZg6CO,2NXHPV7sQrCs8uwcG24fXf,2HGx1UaGs4rGsWytNjraGa,56ORkxVI4aANtLwMVUTWCD,2OSaSXvEqOutRxk29upAiP,3f6uipxNhAsRyUiw2g96FR,2jeNBNsWp8xNd9ZXXj60m9,4rFiU6xcLFkNYKnmTK55i5,33ms3xD1g3jcB9CV3iQfH0,5aZ4JEujY2misHVqElSiN9,2RI11rvIfVXubyOTuOTwXE,1VOSSXuWRcBj2rpfxNdX9v,65DbTqJKhbwqYbZ1Okr0rc,05CjWFAcAlY6O9po6Qwakk,3fqwjXwUGN6vbzIwvyFMhx,7AeM1BGYM7emrqmQn1PuWv,3WMj8moIAXJhHsyLaqIIHI,4KULAymBBJcPRpk1yO4dOG,4gfrYDtaRmp6HPvN80V2ob,2A22iI0x4EYAVXNpKPhNEM,2UikqkwBv7aIvlixeVXHWt,0YsIYFRoxkmEvbKCwTp0Tg,7aLndReanHBzpTGE5Am9H8,4mtmmBBEgdJLYWnLy5zvWE,57TEkZN3f84tFJFHFrD4pO,0n09hxqzKFxW1MBxIjctny,4ZJ4vzLQekI0WntDbanNC7,583dMdiUquLMenarTp7PQm,6ybZUqlfk938oS6WeBmDab,1osfLqL6L2iQsirRf83ded,05ZACkzW8YbRq3eFgIfSNB,6GG4yyk3UATdBfTHVgI8PB,3pAVk6Ydn0dcGpG8gDyxSJ,3xdjjKMcMOFgo1eQrfbogM,0WiyWiJDkNCyGNqkv7NByy,7FudQLDIYCX6F7ruexVn2X,4Sb8neYCkT7lyMIo2kOOEC,2tgQaL85WoRfgEa4hFQgrE with Params: {} returned 403 due to None
# WARNING:recommender:audio features batch error: http status: 403, code: -1 - https://api.spotify.com/v1/audio-features/?ids=2AX5E86cn9n2dgioZEjirI,1cmigB9I6IRpFqjIbzvSQB,5S8pvaRvZzLFvtbaJGxdp3,1AoLEGCko16VHdYsG2POwH,2xizRhme7pYeITbH1NLLGt,2agBDIr9MYDUducQPC1sFU,2NHHKv9F4mYLSMfMl0jayB,5NGtFXVpXSvwunEIGeviY3,4VnDmjYCZkyeqeb0NIKqdA,56oReVXIfUO9xkX7pHmEU0,3U8Fx7zNTQrctytkj6Gqgd,2LKMUX3iN0tQOvggbalydj,6K4uQfVY4NGXQXx9Gq8LQa,2hegfLKqobbWtYPg0Z31vm,3tW8IodDhbGqOzz4i24qjz,3weNRklVDqb4Rr5MhKBR3D,39uLYYZytVUwcjgeYLI409,2vCGb0Sr5ismOhXPliKLRW,3Dgmyz32dxvtxvUTPS0CUI,2SV6rrWHkmxOgV4FwrGxl5,0NqpLq9EZGy9HCK6xWpGep,4Rr3fUE84z8AjJshTRiCWt,5vh2NNTsI6A5pvc9GaYbj7,57udUUmrolC21iP6xtgNBU,5GpfyJrKHJI36jDKtQiyGN,3gS0VrWH2NyPGXYiFmcagd,3gFQOMoUwlR6aUZj81gCzu,7MJ8g0egEkhvGu44IamrDE,2MSgFefjK0T7Iwjvr3OKqV,5UreKbsH9dpfxDB2m6D3Ho,48i1p3R9l9f7zjcHPJysZZ,4XoxeBjlebxva3UpSBULCl,3HJImjLAcnltzIkexQIsJR,4fG5KccAJKYk1EguGbGKt0,7jYydzcZOWVkUFA2q0nQEz,67owhi2vdncwSNE4fEM5Lc,6pnlZLblzKIkPVIojZIplR,5Ic6SKZUhkNusxykGhP31p,7CGrAECnWxyKdSZg29AqoT,1OYjEkmuPByqreZK6IGZiD,62MPgke3glg54RhupICvV9,4hMPpspODHxVP4WbY2T7C1,1dxmixovg25mSp8bESrmMe,7dB6FOZU8mcnij2O9G53wO,1DfGPEHxTYeaJpiNA4xUb5,6XzyCjS2Z2zgGIAk1p5nKB,4DK3JpX2NkEMhCnltUEvUg,4b7FS62swyDhSMk7TBxL57,05wcENjdczP23mxt3qFihI,77oGPqxT7yDZ5OCRmR863C,3EYOJ48Et32uATr9ZmLnAo,4PGrQH5eUSlo8CxdUHRDx3,0g8zASF1mldclJswQ0IQYJ,2Gkwgols6E2yZmBMKeiSRI,0dN8P5k2OymyDJ6GPhIT0n,73QRUJwvitJp80FajryNkK,4DlGLD32K7shuL8ub067DL,6UjiABdNRhHLMWFvRDZSVD,3kfR3pry54a3QhQ1yWVIYN,4SPJDte2kZKgY1Dw2yzmkK,69oIQ9UUcVTopztpOdiwH2,2munHzvVYjZhAa4lj26wcR,37ruL0882SPad6hYhZg6CO,2NXHPV7sQrCs8uwcG24fXf,2HGx1UaGs4rGsWytNjraGa,56ORkxVI4aANtLwMVUTWCD,2OSaSXvEqOutRxk29upAiP,3f6uipxNhAsRyUiw2g96FR,2jeNBNsWp8xNd9ZXXj60m9,4rFiU6xcLFkNYKnmTK55i5,33ms3xD1g3jcB9CV3iQfH0,5aZ4JEujY2misHVqElSiN9,2RI11rvIfVXubyOTuOTwXE,1VOSSXuWRcBj2rpfxNdX9v,65DbTqJKhbwqYbZ1Okr0rc,05CjWFAcAlY6O9po6Qwakk,3fqwjXwUGN6vbzIwvyFMhx,7AeM1BGYM7emrqmQn1PuWv,3WMj8moIAXJhHsyLaqIIHI,4KULAymBBJcPRpk1yO4dOG,4gfrYDtaRmp6HPvN80V2ob,2A22iI0x4EYAVXNpKPhNEM,2UikqkwBv7aIvlixeVXHWt,0YsIYFRoxkmEvbKCwTp0Tg,7aLndReanHBzpTGE5Am9H8,4mtmmBBEgdJLYWnLy5zvWE,57TEkZN3f84tFJFHFrD4pO,0n09hxqzKFxW1MBxIjctny,4ZJ4vzLQekI0WntDbanNC7,583dMdiUquLMenarTp7PQm,6ybZUqlfk938oS6WeBmDab,1osfLqL6L2iQsirRf83ded,05ZACkzW8YbRq3eFgIfSNB,6GG4yyk3UATdBfTHVgI8PB,3pAVk6Ydn0dcGpG8gDyxSJ,3xdjjKMcMOFgo1eQrfbogM,0WiyWiJDkNCyGNqkv7NByy,7FudQLDIYCX6F7ruexVn2X,4Sb8neYCkT7lyMIo2kOOEC,2tgQaL85WoRfgEa4hFQgrE:
#  None, reason: None
# ERROR:spotipy.client:HTTP Error for GET to https://api.spotify.com/v1/audio-features/?ids=1mMLMZYXkMueg65jRRWG1l,1HbzxLqpNVPdiBXvpC7Ovb,4ly1QBXEwYoDmje9rmEgC4,2za9t2qpWyUpIhnJcwopPt,2M38X60UJnupGPbFTkVPNQ,0IRZwSCWFdT5D8hNCXHzZX,3t6gUcGYLrUuqwpXjOFWQc,0eBFgRxyVSeuT4iyrbukdn,13TtTCE6v8vwTSgWJPjwLl,1FHIZknONrV2c20w0x5AVG,5IZXB5IKAD2qlvTPJYDCFB,3Gn1zuHNLtGuGEOXwq0k7e,5eVuVYp9OyD9dm6Wcyb5nr,2PyJAiQjp1OPkow2FJZKHR,58FbmtiyAlFBqFr8EorsSr,1Lo0QY9cvc8sUB2vnIOxDT,0hv6276QhpMDnVJIMxEWPH,4k3lPl8YTKuY8c1HelVnm3,21T9HvQ0KUWFDum6P1Qc7i,2jCJjRc9mz6VYBMhLy3H9i,3EO58D1YpHnTvBy68gK8HE,3K07bGe8iljQ3mOKArHLDo,0JbSghVDghtFEurrSO8JrC,1YYhDizHx7PnDhAhko6cDS,5RuCWf4bJC0rqA05b7nWfd,3wMUvT6eIw2L5cZFG1yH9j,77dcKrzRUI02XjHd2okARp,1QbOvACeYanja5pbnJbAmk,0okmLlOW6vKrilXDvtRMfg,0M7mWKqwTIaVjYyxfZmtTa,31Xa0SpE8683VhZXnJMjjn,7f08qp3HROTkfrtNpiYGGo,7qF0FfuzBFwMe1lNHkEDxW,7K4Y80atyigrNkZZVbOsQ1,0U4iRayct65wsaBMQGiLbg,2DOxC6AdXlSeUrsgWKuX4X,76M3LE85WD1HhntogBmBp1,7wClmUpQfhOY24GVdSGXSd,2abHKI9Oox4NBEhOh3HMbq,5TzoqLAFczwhUMrjNlWITI,0fCwTrRNfoNk962ati8n2K,70RMDSKTArYkHjCsAEgqJT,6o7BCdJjGvHBBPMb4ZrA68,2TXtN9MoV308Y0z1HvyTfV,7pSHLAJyLXjmLsbzqsyQ9D,4Qb4PtmnJl0ANgSiNOxzs4,7E0H1q9wX5gzrUAjjay7PV,6AqwH2Y9FJwhUE2dCSkw1u,0ATvyYvMH3Wlh1O4t0mwdg,454JIJlQ8GvrCoBvSfq3KA,4mwEHjFmDLchZ9uKVhSu7U,69HICMmc6nNLucAx3aJX9M,1IHWl5LamUGEuP4ozKQSXZ,136BeIIoBGrrU9fI1jbcDR,2lTm559tuIvatlT1u0JYG2,3sK8wGT43QFpWrvNQsrQya,3hpm0fTeSqlhJbnqAgaLZs,5TFD2bmFKGhoCRbX61nXY5,6J5kc12BW5HuP3d7C3vvx8,0fea68AdmYNygeTGI4RC18,59D4DOkspUbWyMmbAPQkxZ,0l0vcZMU7AOeQmUIREoI2U,1PREzVLuDT6PSE9sej4wnV,2a1o6ZejUi8U3wzzOtCOYw,4lzo6zPM2paqyP8oBp3DOs,4MjDJD8cW7iVeWInc2Bdyj,6r6IPuFvUX72kQGc9b46rk,58q2HKrzhC3ozto2nDdN4z,4MUrUT38U98olfnyzMBCzm,4e76Ss3ji7HQZ4qwcPNkNA,6QletrrmpkUpeJkipX9pgf,7d6yK8v8J484SWH5prIQiE,6eLQXa6uk2EW8drsiKbABZ,4NyUIohBa3CEMGcXURYSOh,33MeEaRCeIQMSRyFTr5ZJU,5YoITs1m0q8UOQ4AW7N5ga,6VNXmo59yDYgcwLS17UNAW,3D24ErT1MMmUfXWotSj2A2,6Sq7ltF9Qa7SNFBsV5Cogx,69Ej1xrGjOcHvIMtMKxK0G,73scB4Q4fcOmnsBVZPmk32,3e32UUqXzrI4g2y5kNZrwC,1a7onn7lPqqRWul5ogyMyX,1eunv1DeEi29UfAcVEoLTt,0SqqAgdovOE24BzxIClpjw,3k3NWokhRRkEPhCzPmV8TW,4tYFy8ALRjIZvnvSLw5lxN,6RcAHyC5sAUIbPTkhOQwd8,0uQhDYHyoZe5DpncrPolb6,2DEZmgHKAvm41k4J3R2E9Y,5WEF0icHWmAZBBMglBd599,6Xom58OOXk2SoU711L2IXO,6r46lnXFbE9fr2d3KNaGbe,2pbSCYzxrG0wa6qcj8IyiE,3Btqti3QpzZZr6uz5mlNzz,2JJSGhPpATm8lXeYjD95fw,1tz7RZirwiuaJw2p0jbdHb,5Q4HTsEGKanxOwL1nYCnhQ,4ZOkfHC38nxSeSqzGE5HFr,3G7agPwWfcORnWCAGMDOpm with Params: {} returned 403 due to None
# WARNING:recommender:audio features batch error: http status: 403, code: -1 - https://api.spotify.com/v1/audio-features/?ids=1mMLMZYXkMueg65jRRWG1l,1HbzxLqpNVPdiBXvpC7Ovb,4ly1QBXEwYoDmje9rmEgC4,2za9t2qpWyUpIhnJcwopPt,2M38X60UJnupGPbFTkVPNQ,0IRZwSCWFdT5D8hNCXHzZX,3t6gUcGYLrUuqwpXjOFWQc,0eBFgRxyVSeuT4iyrbukdn,13TtTCE6v8vwTSgWJPjwLl,1FHIZknONrV2c20w0x5AVG,5IZXB5IKAD2qlvTPJYDCFB,3Gn1zuHNLtGuGEOXwq0k7e,5eVuVYp9OyD9dm6Wcyb5nr,2PyJAiQjp1OPkow2FJZKHR,58FbmtiyAlFBqFr8EorsSr,1Lo0QY9cvc8sUB2vnIOxDT,0hv6276QhpMDnVJIMxEWPH,4k3lPl8YTKuY8c1HelVnm3,21T9HvQ0KUWFDum6P1Qc7i,2jCJjRc9mz6VYBMhLy3H9i,3EO58D1YpHnTvBy68gK8HE,3K07bGe8iljQ3mOKArHLDo,0JbSghVDghtFEurrSO8JrC,1YYhDizHx7PnDhAhko6cDS,5RuCWf4bJC0rqA05b7nWfd,3wMUvT6eIw2L5cZFG1yH9j,77dcKrzRUI02XjHd2okARp,1QbOvACeYanja5pbnJbAmk,0okmLlOW6vKrilXDvtRMfg,0M7mWKqwTIaVjYyxfZmtTa,31Xa0SpE8683VhZXnJMjjn,7f08qp3HROTkfrtNpiYGGo,7qF0FfuzBFwMe1lNHkEDxW,7K4Y80atyigrNkZZVbOsQ1,0U4iRayct65wsaBMQGiLbg,2DOxC6AdXlSeUrsgWKuX4X,76M3LE85WD1HhntogBmBp1,7wClmUpQfhOY24GVdSGXSd,2abHKI9Oox4NBEhOh3HMbq,5TzoqLAFczwhUMrjNlWITI,0fCwTrRNfoNk962ati8n2K,70RMDSKTArYkHjCsAEgqJT,6o7BCdJjGvHBBPMb4ZrA68,2TXtN9MoV308Y0z1HvyTfV,7pSHLAJyLXjmLsbzqsyQ9D,4Qb4PtmnJl0ANgSiNOxzs4,7E0H1q9wX5gzrUAjjay7PV,6AqwH2Y9FJwhUE2dCSkw1u,0ATvyYvMH3Wlh1O4t0mwdg,454JIJlQ8GvrCoBvSfq3KA,4mwEHjFmDLchZ9uKVhSu7U,69HICMmc6nNLucAx3aJX9M,1IHWl5LamUGEuP4ozKQSXZ,136BeIIoBGrrU9fI1jbcDR,2lTm559tuIvatlT1u0JYG2,3sK8wGT43QFpWrvNQsrQya,3hpm0fTeSqlhJbnqAgaLZs,5TFD2bmFKGhoCRbX61nXY5,6J5kc12BW5HuP3d7C3vvx8,0fea68AdmYNygeTGI4RC18,59D4DOkspUbWyMmbAPQkxZ,0l0vcZMU7AOeQmUIREoI2U,1PREzVLuDT6PSE9sej4wnV,2a1o6ZejUi8U3wzzOtCOYw,4lzo6zPM2paqyP8oBp3DOs,4MjDJD8cW7iVeWInc2Bdyj,6r6IPuFvUX72kQGc9b46rk,58q2HKrzhC3ozto2nDdN4z,4MUrUT38U98olfnyzMBCzm,4e76Ss3ji7HQZ4qwcPNkNA,6QletrrmpkUpeJkipX9pgf,7d6yK8v8J484SWH5prIQiE,6eLQXa6uk2EW8drsiKbABZ,4NyUIohBa3CEMGcXURYSOh,33MeEaRCeIQMSRyFTr5ZJU,5YoITs1m0q8UOQ4AW7N5ga,6VNXmo59yDYgcwLS17UNAW,3D24ErT1MMmUfXWotSj2A2,6Sq7ltF9Qa7SNFBsV5Cogx,69Ej1xrGjOcHvIMtMKxK0G,73scB4Q4fcOmnsBVZPmk32,3e32UUqXzrI4g2y5kNZrwC,1a7onn7lPqqRWul5ogyMyX,1eunv1DeEi29UfAcVEoLTt,0SqqAgdovOE24BzxIClpjw,3k3NWokhRRkEPhCzPmV8TW,4tYFy8ALRjIZvnvSLw5lxN,6RcAHyC5sAUIbPTkhOQwd8,0uQhDYHyoZe5DpncrPolb6,2DEZmgHKAvm41k4J3R2E9Y,5WEF0icHWmAZBBMglBd599,6Xom58OOXk2SoU711L2IXO,6r46lnXFbE9fr2d3KNaGbe,2pbSCYzxrG0wa6qcj8IyiE,3Btqti3QpzZZr6uz5mlNzz,2JJSGhPpATm8lXeYjD95fw,1tz7RZirwiuaJw2p0jbdHb,5Q4HTsEGKanxOwL1nYCnhQ,4ZOkfHC38nxSeSqzGE5HFr,3G7agPwWfcORnWCAGMDOpm:
#  None, reason: None
# ERROR:spotipy.client:HTTP Error for GET to https://api.spotify.com/v1/audio-features/?ids=1YYfyJ2yCvGFCxwjsIqEK9,2beS6dD5rovBxSA1zYoSHR,2KrQbq3aqGOFGnkTKnN2XA,4wtWL0UV8tCPv9VbUMLXYP,4emEXP671dnpn1thHrogSe,4Z6pPinNzkGtbgAlE88263,1ZunPTRc0PUFfdSWa3qMB1,712KzUVmtBeFXgJhbMJY5o,1xuYajTJZh8zZrPRmUaagf,1zLBsSVxETQOfINOLYvT5m,10MpBpx64MNixmUMNj7f6b,1dyA1Re4QEQQWGDDT7h9TK,1TWAUx1pXxA5XxJmHMGT0b,39PPT5p915YbhBfa8GWi4H,2L1lCDnKE9WcnTEre5QKCP,4WefXOf8I4gMjdj2kBJgkl,5miJeYpwbtZLo9ryB4hpFM,0gELGDQ3XTZUdFQ6GAyCkA,1UTLq40xh63wMrHELGnKWW,4Yjw3kv7WB1pzv8YaiAkNR,7h9mteAF6ZQDh7QsnI7JZT,1AZbs0L3SkXe625DKp37KQ,3b5hWg2x9MoVM7wjZ3qiY6,24u8UoasXiwBenoAm5K6Im,4BMXWNoWQs5fylwuYeAh8f,68HZeyktDHYYYwZiMoAhMx,1tEsmmnnJEjkRYWgUq8lAe,6J53VAHFT1iKYAlzppZXBn,6QrgxKiGjdJ5wOmZvGzWPu,2QjOHCTQ1Jl3zawyYOpxh6,0mflMxspEfB0VbI1kyLiAv,77zqs8ucHCSk5jh9TYec4b,0AV4GhGeGCVJphsMTxDWdE,0InIeZW4P6VO7dUGRM4AKH,1oAwsWBovWRIp7qLMGPIet,0TFTAtCYhp2tQ9KcJIZb55,2uXlHCUbq9OMUwx3hrk06o,1LzNfuep1bnAUR9skqdHCK,5vPUv0xziXbV4lnWeVNXNq,0FTmksd2dxiE5e3rWyJXs6,4RvWPyQ5RL0ao9LPZeSouE,7EkWXAI1wn8Ii883ecd9xr,52ojopYMUzeNcudsoz7O9D,6QeYSvYqYUsfBzsApbjDHO,3IznIgmXtrUaoPWpQTy5jB,2tznHmp70DxMyr2XhWLOW0,3rKjT23XeGg3pbqE1T1fpd,0sTlGEld0h8kIPZaKDYUf4,0GO8y8jQk1PkHzS31d699N,2R4AlwtrrkMaRKojcTIzmL,4S4QJfBGGrC8jRIjJHf1Ka,41P6Tnd8KIHqON0QIydx6a,5E30LdtzQTGqRvNd7l6kG5,6gZVQvQZOFpzIy3HblJ20F,2JuasWPUodaUxf5nwNpciQ,5Xak5fmy089t0FYmh3VJiY,4iZxeyibg6w4EFCOoAQ6Eh,7H0ya83CMmgFcOhw0UB6ow,086myS9r57YsLbJpU0TgK9,57iDDD9N9tTWe75x6qhStw,7mDTvYD2ieE4Q28XFziMfJ,39sDitIeCMrVX2QyXHY46t,2K7xn816oNHJZ0aVqdQsha,11LmqTE2naFULdEP94AUBa,3SeDS5sSoWnwAZvVgkdKzf,3FtYbEfBqAlGO46NUDQSAt,2J051fjLklkoPbzOoTAACZ,0URBL54h1GTCBg6Y7Jj3HG,7rSuqMaEloVncVc8RDdoDX,4twrPigd0WUg9hbL0FmuAM,4hOg5mPplqNDKZE6pyiYwz,7xKtm7nXBMwdQTkHyL1m3d,1wbba6PHMvfYECI07VsfNl,7bvq3VGQZJBJGNXEiC8kx6,6WgFz2K097dHGcPxUGMJmU,478ACo993LBxkU3Sv8Vsua,6oVdkLtgzrDmeNisp9o4mc,4M8YuQqB6GIAz4N09nZn8t,4OU4JK6MhbUYM2ApUOaUVq,4hN5TRMGnnTuE0NWW6otIE,3hmhttFojkyiUoiVWvPoj2,3JOrcc5gB6oBA9eGJ1kY6N,3S04lhLcIP2IAgv2ifq2UC,6OhY6laZEBXfn0oa78nhAX,6kn6aRCa7AMLSYasPvQlYV,10R0WbF7ekdbScY5XRvCYY,4MokzxduPUwwLwS92Q5fMM,7EDPtTTKlfj0WZVDHcNSYD,4N5guglVJdjG8eZOQedJMW,59c2xv2kMzYM6HR9oY6BIa,3mGzSsQlysRFZTfAdC9547,3EAve58QUdqp9VRaJEephI,2NDoK87du1jK5yd6b63Hmz,5XJGXVAxjAbb3ZAlnnHAst,2JVIsyJCZliq33d2hIvMgh,3K4HG9evC7dg3N0R9cYqk4,5cZqsjVs6MevCnAkasbEOX,18lR4BzEs7e3qzc0KVkTpU,70L6nHORQsblY813yNqUR3,0snQkGI5qnAmohLE7jTsTn with Params: {} returned 403 due to None
# WARNING:recommender:audio features batch error: http status: 403, code: -1 - https://api.spotify.com/v1/audio-features/?ids=1YYfyJ2yCvGFCxwjsIqEK9,2beS6dD5rovBxSA1zYoSHR,2KrQbq3aqGOFGnkTKnN2XA,4wtWL0UV8tCPv9VbUMLXYP,4emEXP671dnpn1thHrogSe,4Z6pPinNzkGtbgAlE88263,1ZunPTRc0PUFfdSWa3qMB1,712KzUVmtBeFXgJhbMJY5o,1xuYajTJZh8zZrPRmUaagf,1zLBsSVxETQOfINOLYvT5m,10MpBpx64MNixmUMNj7f6b,1dyA1Re4QEQQWGDDT7h9TK,1TWAUx1pXxA5XxJmHMGT0b,39PPT5p915YbhBfa8GWi4H,2L1lCDnKE9WcnTEre5QKCP,4WefXOf8I4gMjdj2kBJgkl,5miJeYpwbtZLo9ryB4hpFM,0gELGDQ3XTZUdFQ6GAyCkA,1UTLq40xh63wMrHELGnKWW,4Yjw3kv7WB1pzv8YaiAkNR,7h9mteAF6ZQDh7QsnI7JZT,1AZbs0L3SkXe625DKp37KQ,3b5hWg2x9MoVM7wjZ3qiY6,24u8UoasXiwBenoAm5K6Im,4BMXWNoWQs5fylwuYeAh8f,68HZeyktDHYYYwZiMoAhMx,1tEsmmnnJEjkRYWgUq8lAe,6J53VAHFT1iKYAlzppZXBn,6QrgxKiGjdJ5wOmZvGzWPu,2QjOHCTQ1Jl3zawyYOpxh6,0mflMxspEfB0VbI1kyLiAv,77zqs8ucHCSk5jh9TYec4b,0AV4GhGeGCVJphsMTxDWdE,0InIeZW4P6VO7dUGRM4AKH,1oAwsWBovWRIp7qLMGPIet,0TFTAtCYhp2tQ9KcJIZb55,2uXlHCUbq9OMUwx3hrk06o,1LzNfuep1bnAUR9skqdHCK,5vPUv0xziXbV4lnWeVNXNq,0FTmksd2dxiE5e3rWyJXs6,4RvWPyQ5RL0ao9LPZeSouE,7EkWXAI1wn8Ii883ecd9xr,52ojopYMUzeNcudsoz7O9D,6QeYSvYqYUsfBzsApbjDHO,3IznIgmXtrUaoPWpQTy5jB,2tznHmp70DxMyr2XhWLOW0,3rKjT23XeGg3pbqE1T1fpd,0sTlGEld0h8kIPZaKDYUf4,0GO8y8jQk1PkHzS31d699N,2R4AlwtrrkMaRKojcTIzmL,4S4QJfBGGrC8jRIjJHf1Ka,41P6Tnd8KIHqON0QIydx6a,5E30LdtzQTGqRvNd7l6kG5,6gZVQvQZOFpzIy3HblJ20F,2JuasWPUodaUxf5nwNpciQ,5Xak5fmy089t0FYmh3VJiY,4iZxeyibg6w4EFCOoAQ6Eh,7H0ya83CMmgFcOhw0UB6ow,086myS9r57YsLbJpU0TgK9,57iDDD9N9tTWe75x6qhStw,7mDTvYD2ieE4Q28XFziMfJ,39sDitIeCMrVX2QyXHY46t,2K7xn816oNHJZ0aVqdQsha,11LmqTE2naFULdEP94AUBa,3SeDS5sSoWnwAZvVgkdKzf,3FtYbEfBqAlGO46NUDQSAt,2J051fjLklkoPbzOoTAACZ,0URBL54h1GTCBg6Y7Jj3HG,7rSuqMaEloVncVc8RDdoDX,4twrPigd0WUg9hbL0FmuAM,4hOg5mPplqNDKZE6pyiYwz,7xKtm7nXBMwdQTkHyL1m3d,1wbba6PHMvfYECI07VsfNl,7bvq3VGQZJBJGNXEiC8kx6,6WgFz2K097dHGcPxUGMJmU,478ACo993LBxkU3Sv8Vsua,6oVdkLtgzrDmeNisp9o4mc,4M8YuQqB6GIAz4N09nZn8t,4OU4JK6MhbUYM2ApUOaUVq,4hN5TRMGnnTuE0NWW6otIE,3hmhttFojkyiUoiVWvPoj2,3JOrcc5gB6oBA9eGJ1kY6N,3S04lhLcIP2IAgv2ifq2UC,6OhY6laZEBXfn0oa78nhAX,6kn6aRCa7AMLSYasPvQlYV,10R0WbF7ekdbScY5XRvCYY,4MokzxduPUwwLwS92Q5fMM,7EDPtTTKlfj0WZVDHcNSYD,4N5guglVJdjG8eZOQedJMW,59c2xv2kMzYM6HR9oY6BIa,3mGzSsQlysRFZTfAdC9547,3EAve58QUdqp9VRaJEephI,2NDoK87du1jK5yd6b63Hmz,5XJGXVAxjAbb3ZAlnnHAst,2JVIsyJCZliq33d2hIvMgh,3K4HG9evC7dg3N0R9cYqk4,5cZqsjVs6MevCnAkasbEOX,18lR4BzEs7e3qzc0KVkTpU,70L6nHORQsblY813yNqUR3,0snQkGI5qnAmohLE7jTsTn:
#  None, reason: None
# ERROR:spotipy.client:HTTP Error for GET to https://api.spotify.com/v1/audio-features/?ids=6Nm8h73ycDG2saCnZV8poF,5W8YXBz9MTIDyrpYaCg2Ky,4Uiw0Sl9yskBaC6P4DcdVD,61mWefnWQOLf90gepjOCb3,4e9eGQYsOiBcftrWXwsVco,3IV4swNduIRunHREK80owz,4Yqy0GpeDEXLibWJCZyQew,54bm2e3tk8cliUz3VSdCPZ,7CpbhqKUedOIrcvc94p60Y,57BrRMwf9LrcmuOsyGilwr,1VNWaY3uNfoeWqb5U8x2QX,4bLCPfBLKlqiONo6TALTh5,31rneVrsMC6jefCoDyQKam,0UFDKFqW2oGspYeYqo9wjA,3o7TMr6RmIusYH7Kkg7ujR,1EryAkZ0VHstC6haIxVBiE,6W21LNLz9Sw7sUSNWMSHRu,0LAcM6I7ijW4VVW0aytl1t,51YZAJhOwIC5Gg3jMbAmhZ,2CGDxXXYbkPOyRXHzQbqkT,40rvBMQizxkIqnjPdEWY1v,1pr9TZGOXeJUggIal1Wq3R,1Vej0qeQ3ioKwpI6FUbRv1,1fLlRApgzxWweF1JTf8yM5,3BmjRmFTESgWZLPSVGp8aG,2gSVKxPDww9Eep5rdvtdem,0ee1DiZF94NSqqpG0XHUzH,2CtemffYhT0DJWcT1XW047,089jl361OtZ6VpYvhgPiTS,7w6PJe5KBPyvuRYxFkPssC,46odPfzMypgxCBMUPmdKxr,3RAFcUBrCNaboRXoP3S5t1,4otwFzkVBdVNTBu7gxJA4A,6wqJeItl3Vc3az4ZicSQAB,4FEr6dIdH6EqLKR0jB560J,6DyywdbmTzlmXBzG9ym7Rt,0lqHgjNrXmtFroWDqwV1iQ,5DrNFzZZZVfXaEZCaceKnp,745sNpjWbAxo2MA2zSYbyD,28clONjZmul6FjfO6tZQDE,0dqGfCMAGyDgpUAgLNOjWd,3UULkHdmLDqBDPmBYltoRE,1tTPC0hsnXq1IGpvWY54JC,1GoQ5EQ0ZNURRrJKdThflm,7lwvxYumAEo10lzAplRGXM,5UaDi8KzCGJqFfVAOBfXhi,36DLF96pjKydN0MZtsahQz,3ZpWy5rBZv2aLQAldnmTsP,0ctinu4CJdYf9QaCmdzMST,7oMA3qs18aC69Cr4k6EAyn,7HPhrbgMHV5cUskknWA2oo,4q9QVIaLqjbcoqeCfM2zan,0IGXkVRn0uCsgn4FvIfpgB,4SRUqprqmYkhxh1W01OcAs,4xyWJM4kscTROV2RESdwpd,7LHZ7HA45ezKcdN8sBrBuS,5SC2o4WyHL3dxbjn4TLOkU,5gQ0LTbcX7gpQDg39gNLH8,6ZT36tXEKY2vvTCuNK4fi1,7wz8LNfmGZ3C0PwKW9LdDg,0jjXOQfu0Lq5WDOSADoJI4,7FcLgWXLFyAmDrKXIDNwcF,1HuuFLjgjIfzMFgGuZjv4Z,0H4fQFdmbkARxfqEUVAXPY,0DwClY2t9YAWHBROMIgrXb,54uoj9Bb6k97wSQ9MezOYU,7ByxizhA4GgEf7Sxomxhze,4O2rRsoSPb5aN7N3tG6Y3v,4IU1RL4BKvFyXtbTwaHAvW,6HSXNV0b4M4cLJ7ljgVVeh,2ixsaeFioXJmMgkkbd4uj1,6MAev6g8Vz8UF7QfFlb6JD,14AyWf6y7KlWWLfAjdKMKI,2ihCaVdNZmnHZWt0fvAM7B,6oCXDaFZYL7sHnowv6pdXb,3nEotpBFeXq0OJstuHzwDP,5VSAonaAPhhGn0G7hMYwWK,6PdWPdgPoVCT9WLFMVnhxx,07UFnnK3uPIuKv5Rs9TmXl,5HXFe0eb5lCfJpsqoqIbRS,0WAEGVylZjbe2mQ6Or6HxY,4PwWESSlTwzvw9B7bmtTLS,1HMQmOWrkieKYWlFsjUP3D,3Pbp7cUCx4d3OAkZSCoNvn,1JlssWnwFUiEzuSqw4H1V1,3mg2GWeQoe9QnXizWvyAr2,3Bclyko7WmwM2oGmKj8sue,3lh3iiiJeiBXHSZw6u0kh6,1M39ETXmej4g9EMSeXPUgj,7yq4Qj7cqayVTp3FF9CWbm,2VlikHNvR4PcBzQwJBGqzt,0SjnBEHZVXgCKvOrpvzL2k,6naFuQGWFBHThc3fppOjbT,3hEkAosl2ZuO9FltxY5L1R,7mjSHL2Eb0kAwiKbvNNyD9,2AXY5WABx7NjWw1zb4qCdc,1o5WgxPWvoVgo20DQItKOE,5RgFlk1fcClZd0Y4SGYhqH,4mQtXW0vrHC3oTkA1mQsb0,6m8jy0dNtYqVi5c4EtLZdM with Params: {} returned 403 due to None
# WARNING:recommender:audio features batch error: http status: 403, code: -1 - https://api.spotify.com/v1/audio-features/?ids=6Nm8h73ycDG2saCnZV8poF,5W8YXBz9MTIDyrpYaCg2Ky,4Uiw0Sl9yskBaC6P4DcdVD,61mWefnWQOLf90gepjOCb3,4e9eGQYsOiBcftrWXwsVco,3IV4swNduIRunHREK80owz,4Yqy0GpeDEXLibWJCZyQew,54bm2e3tk8cliUz3VSdCPZ,7CpbhqKUedOIrcvc94p60Y,57BrRMwf9LrcmuOsyGilwr,1VNWaY3uNfoeWqb5U8x2QX,4bLCPfBLKlqiONo6TALTh5,31rneVrsMC6jefCoDyQKam,0UFDKFqW2oGspYeYqo9wjA,3o7TMr6RmIusYH7Kkg7ujR,1EryAkZ0VHstC6haIxVBiE,6W21LNLz9Sw7sUSNWMSHRu,0LAcM6I7ijW4VVW0aytl1t,51YZAJhOwIC5Gg3jMbAmhZ,2CGDxXXYbkPOyRXHzQbqkT,40rvBMQizxkIqnjPdEWY1v,1pr9TZGOXeJUggIal1Wq3R,1Vej0qeQ3ioKwpI6FUbRv1,1fLlRApgzxWweF1JTf8yM5,3BmjRmFTESgWZLPSVGp8aG,2gSVKxPDww9Eep5rdvtdem,0ee1DiZF94NSqqpG0XHUzH,2CtemffYhT0DJWcT1XW047,089jl361OtZ6VpYvhgPiTS,7w6PJe5KBPyvuRYxFkPssC,46odPfzMypgxCBMUPmdKxr,3RAFcUBrCNaboRXoP3S5t1,4otwFzkVBdVNTBu7gxJA4A,6wqJeItl3Vc3az4ZicSQAB,4FEr6dIdH6EqLKR0jB560J,6DyywdbmTzlmXBzG9ym7Rt,0lqHgjNrXmtFroWDqwV1iQ,5DrNFzZZZVfXaEZCaceKnp,745sNpjWbAxo2MA2zSYbyD,28clONjZmul6FjfO6tZQDE,0dqGfCMAGyDgpUAgLNOjWd,3UULkHdmLDqBDPmBYltoRE,1tTPC0hsnXq1IGpvWY54JC,1GoQ5EQ0ZNURRrJKdThflm,7lwvxYumAEo10lzAplRGXM,5UaDi8KzCGJqFfVAOBfXhi,36DLF96pjKydN0MZtsahQz,3ZpWy5rBZv2aLQAldnmTsP,0ctinu4CJdYf9QaCmdzMST,7oMA3qs18aC69Cr4k6EAyn,7HPhrbgMHV5cUskknWA2oo,4q9QVIaLqjbcoqeCfM2zan,0IGXkVRn0uCsgn4FvIfpgB,4SRUqprqmYkhxh1W01OcAs,4xyWJM4kscTROV2RESdwpd,7LHZ7HA45ezKcdN8sBrBuS,5SC2o4WyHL3dxbjn4TLOkU,5gQ0LTbcX7gpQDg39gNLH8,6ZT36tXEKY2vvTCuNK4fi1,7wz8LNfmGZ3C0PwKW9LdDg,0jjXOQfu0Lq5WDOSADoJI4,7FcLgWXLFyAmDrKXIDNwcF,1HuuFLjgjIfzMFgGuZjv4Z,0H4fQFdmbkARxfqEUVAXPY,0DwClY2t9YAWHBROMIgrXb,54uoj9Bb6k97wSQ9MezOYU,7ByxizhA4GgEf7Sxomxhze,4O2rRsoSPb5aN7N3tG6Y3v,4IU1RL4BKvFyXtbTwaHAvW,6HSXNV0b4M4cLJ7ljgVVeh,2ixsaeFioXJmMgkkbd4uj1,6MAev6g8Vz8UF7QfFlb6JD,14AyWf6y7KlWWLfAjdKMKI,2ihCaVdNZmnHZWt0fvAM7B,6oCXDaFZYL7sHnowv6pdXb,3nEotpBFeXq0OJstuHzwDP,5VSAonaAPhhGn0G7hMYwWK,6PdWPdgPoVCT9WLFMVnhxx,07UFnnK3uPIuKv5Rs9TmXl,5HXFe0eb5lCfJpsqoqIbRS,0WAEGVylZjbe2mQ6Or6HxY,4PwWESSlTwzvw9B7bmtTLS,1HMQmOWrkieKYWlFsjUP3D,3Pbp7cUCx4d3OAkZSCoNvn,1JlssWnwFUiEzuSqw4H1V1,3mg2GWeQoe9QnXizWvyAr2,3Bclyko7WmwM2oGmKj8sue,3lh3iiiJeiBXHSZw6u0kh6,1M39ETXmej4g9EMSeXPUgj,7yq4Qj7cqayVTp3FF9CWbm,2VlikHNvR4PcBzQwJBGqzt,0SjnBEHZVXgCKvOrpvzL2k,6naFuQGWFBHThc3fppOjbT,3hEkAosl2ZuO9FltxY5L1R,7mjSHL2Eb0kAwiKbvNNyD9,2AXY5WABx7NjWw1zb4qCdc,1o5WgxPWvoVgo20DQItKOE,5RgFlk1fcClZd0Y4SGYhqH,4mQtXW0vrHC3oTkA1mQsb0,6m8jy0dNtYqVi5c4EtLZdM:
#  None, reason: None
# ERROR:spotipy.client:HTTP Error for GET to https://api.spotify.com/v1/audio-features/?ids=4sDbdBjuYQVdNNB4PiHUPo,1EAgPzRbK9YmdOESSMUm6P,32iNr3J93tqFkxaMYwdRYi,7GjxQQQD9jYCF2Eeh2HHcT,4uTTd2SlalZoG0zVgI63kH,1EgeiGYBJouzsieXUiX2wF,3Kj2EWpIBnvETsYq4cq0IH,67q8yivDoOPXCYodi1zTix,0MpQPb1hrwk4dPiyWEGmer,7FM4XWxl4sZe8Yq5Zg6lsn,5tcNBT4NxK7osenJbOUudX,6wTPFOm5KMpO84GXcBAWvU,4ThWyZnBqdPBiLk32ARCpZ,2fcYfbgSqHDyYoSL2l0Osb,7bNQvH1gTydxfIetHX3WGC,1uOpGeKg6ikCb9YM2Hgbpb,4R2kfaDFhslZEMJqAFNpdd,4dyx5SzxPPaD8xQIid5Wjj,0x6RJeywbl3my9z2qmHt2g,7HRXNiDIt5QSeZSmNePxij,26rk3x8uh1Xtq5RCvBstMB,2MTomvRO4nwpaXBg2QXxUf,19R61PjvSy7OBegMWOu6rF,3hUxzQpSfdDqwM3ZTFQY0K,2Kwzf7pXy39kpR883WyThi,3escodrAC8qMlzeFthB6Dn,0zFaU5c5n6avS53A9GMdHw,1NKnPxWXjoPEITozVtxUSM,4Ykx6Qf1oQ7MNlJqz8P6KI,6ZRQyJD8pFkmwyBNdPUOL9,3Vr3zh0r7ALn8VLqCiRR10,401pp3i4Cvth63rXH8ZLXO,63nRWHOW6qj9D63AIBOOpS,7whSj4Xqg7kb13OfnU3miJ,0aGlC7ndhKHJINaaT2QWSY,5TgEJ62DOzBpGxZ7WRsrqb,2aGPscectunIyAPBTPZEbZ,7rgQdKg2reFNxo2r8DAFNK,3WDfAzsYvmOuco2PN18hr9,7udBOAP2LPGvrUw03rXf4H,46ZI02LajLi464kBUgJTuh,4a2uqVlpRChHj32EjJLu7G,6fhgO6p9DsTyHqPctyzDkV,1KZG1H1OCugGqIRmk1wF9m,5j4hSQH0KaAc8f6cimnXIT,3HxEGE7XpzqTVHEui3IMyb,1s0B0dkZHfynScpLO0UzJX,3i86MS9vF1VCf0h2IEpKWY,7siXHCf5qUbyJrhNYQXKFr,1r04a90d5sggiNbr6w4oGO,43UV5Uk0ntzH6MP8Rx1RKh,1rnYNAJPAb586NhetosdNW,1YzIpqwnj5M8qylwn1Tr9Z,78Du4CMFgnhdlG33gblkiP,24nhOvYX2gk3txBbMzXeUB,0yiW81qj0xsPPljEDAyhJ5,7dUdMZqfGSIt0ZkmTOgRLA,4jB3Mw900goYibsFAueHph,3fBLo7dnG5CSepoXgu3B53,6OuMqLdjmNJvrJSp0J6f8U,3s5NrHgyTkuinl0TgHCHeK,2E6HksJPriDYu6thbR6xrV,30LZU3ReFIndjHLfaahreM,3cohjFTLMRmx8xQbd5dpX5,7DQjWFjaiPULrsqgsZueF3,0synZpsRWT8bQ8Fz4nPpM3,2ySKl9oGwZMZzXJraNiNgl,65BmUqyPuH4QLfQjcoJPFL,1PZ9ncnWkilczGmeMG2PJf,17HsyeI0Eq06n3XRntZ4DT,5oEM9EDKL9y4XLTJzi0g96,0duALa6UlxVWqEqpmhv73p,70Iv0DGdoPCCjE6L2uTq28,5RQsNib1m9Hxo2AIjJcdpK,5aDK0TurEtiedVdT0a6k9a,2mqAwLuAZBIVEAOaDTScEm,7E47zOXHdx0Ob0Bu5GxCs6,3lsWwQnDg99gtni4g5V0UG,2nKZMOEvOyTViP09HxBfXx,3BCsNM2w6HcCbrVWlhjTpk,4eMxLQtSdgxdA1Hs6D2YuN,4y3Aq2Ey7TG4KsY5KZPD6m,6Oexp3W6bv5LBzsS171iqN,0Uybrtb766jul6WpkjqbID,1nFusfst42jPWjXa8EAhyE,4Zs63yXBLMPHg6Q9gYoaxs,714tF0Vt9ohC9uWwEyIRAo,1a2iF9XymafjRk56q7oCxo,6vuVCtwukUA57ioTnKKeuL,41goAg1ZxePWjXXfZ7PhG7,27gxr3Bsfr42U1Fx32a0Ul,27IRo2rYeizhRMDaNVplNM,5IirHic5goVkgpxyur1lmh,500Tkm3vJmVtdUwdCVxCTb,1U6KEQuL5wPJZMR0iHvzqh,7u1P36qRqrSNrXAp98cyp1,1aM9ClS0qz0Fp2BjmbM72M,11iIikXxC6NP0Ma8vMD27x,73vWnvPaf0yNifYIkadY9N,4J4wYsDnJxldGxAiFpIIzT with Params: {} returned 403 due to None
# WARNING:recommender:audio features batch error: http status: 403, code: -1 - https://api.spotify.com/v1/audio-features/?ids=4sDbdBjuYQVdNNB4PiHUPo,1EAgPzRbK9YmdOESSMUm6P,32iNr3J93tqFkxaMYwdRYi,7GjxQQQD9jYCF2Eeh2HHcT,4uTTd2SlalZoG0zVgI63kH,1EgeiGYBJouzsieXUiX2wF,3Kj2EWpIBnvETsYq4cq0IH,67q8yivDoOPXCYodi1zTix,0MpQPb1hrwk4dPiyWEGmer,7FM4XWxl4sZe8Yq5Zg6lsn,5tcNBT4NxK7osenJbOUudX,6wTPFOm5KMpO84GXcBAWvU,4ThWyZnBqdPBiLk32ARCpZ,2fcYfbgSqHDyYoSL2l0Osb,7bNQvH1gTydxfIetHX3WGC,1uOpGeKg6ikCb9YM2Hgbpb,4R2kfaDFhslZEMJqAFNpdd,4dyx5SzxPPaD8xQIid5Wjj,0x6RJeywbl3my9z2qmHt2g,7HRXNiDIt5QSeZSmNePxij,26rk3x8uh1Xtq5RCvBstMB,2MTomvRO4nwpaXBg2QXxUf,19R61PjvSy7OBegMWOu6rF,3hUxzQpSfdDqwM3ZTFQY0K,2Kwzf7pXy39kpR883WyThi,3escodrAC8qMlzeFthB6Dn,0zFaU5c5n6avS53A9GMdHw,1NKnPxWXjoPEITozVtxUSM,4Ykx6Qf1oQ7MNlJqz8P6KI,6ZRQyJD8pFkmwyBNdPUOL9,3Vr3zh0r7ALn8VLqCiRR10,401pp3i4Cvth63rXH8ZLXO,63nRWHOW6qj9D63AIBOOpS,7whSj4Xqg7kb13OfnU3miJ,0aGlC7ndhKHJINaaT2QWSY,5TgEJ62DOzBpGxZ7WRsrqb,2aGPscectunIyAPBTPZEbZ,7rgQdKg2reFNxo2r8DAFNK,3WDfAzsYvmOuco2PN18hr9,7udBOAP2LPGvrUw03rXf4H,46ZI02LajLi464kBUgJTuh,4a2uqVlpRChHj32EjJLu7G,6fhgO6p9DsTyHqPctyzDkV,1KZG1H1OCugGqIRmk1wF9m,5j4hSQH0KaAc8f6cimnXIT,3HxEGE7XpzqTVHEui3IMyb,1s0B0dkZHfynScpLO0UzJX,3i86MS9vF1VCf0h2IEpKWY,7siXHCf5qUbyJrhNYQXKFr,1r04a90d5sggiNbr6w4oGO,43UV5Uk0ntzH6MP8Rx1RKh,1rnYNAJPAb586NhetosdNW,1YzIpqwnj5M8qylwn1Tr9Z,78Du4CMFgnhdlG33gblkiP,24nhOvYX2gk3txBbMzXeUB,0yiW81qj0xsPPljEDAyhJ5,7dUdMZqfGSIt0ZkmTOgRLA,4jB3Mw900goYibsFAueHph,3fBLo7dnG5CSepoXgu3B53,6OuMqLdjmNJvrJSp0J6f8U,3s5NrHgyTkuinl0TgHCHeK,2E6HksJPriDYu6thbR6xrV,30LZU3ReFIndjHLfaahreM,3cohjFTLMRmx8xQbd5dpX5,7DQjWFjaiPULrsqgsZueF3,0synZpsRWT8bQ8Fz4nPpM3,2ySKl9oGwZMZzXJraNiNgl,65BmUqyPuH4QLfQjcoJPFL,1PZ9ncnWkilczGmeMG2PJf,17HsyeI0Eq06n3XRntZ4DT,5oEM9EDKL9y4XLTJzi0g96,0duALa6UlxVWqEqpmhv73p,70Iv0DGdoPCCjE6L2uTq28,5RQsNib1m9Hxo2AIjJcdpK,5aDK0TurEtiedVdT0a6k9a,2mqAwLuAZBIVEAOaDTScEm,7E47zOXHdx0Ob0Bu5GxCs6,3lsWwQnDg99gtni4g5V0UG,2nKZMOEvOyTViP09HxBfXx,3BCsNM2w6HcCbrVWlhjTpk,4eMxLQtSdgxdA1Hs6D2YuN,4y3Aq2Ey7TG4KsY5KZPD6m,6Oexp3W6bv5LBzsS171iqN,0Uybrtb766jul6WpkjqbID,1nFusfst42jPWjXa8EAhyE,4Zs63yXBLMPHg6Q9gYoaxs,714tF0Vt9ohC9uWwEyIRAo,1a2iF9XymafjRk56q7oCxo,6vuVCtwukUA57ioTnKKeuL,41goAg1ZxePWjXXfZ7PhG7,27gxr3Bsfr42U1Fx32a0Ul,27IRo2rYeizhRMDaNVplNM,5IirHic5goVkgpxyur1lmh,500Tkm3vJmVtdUwdCVxCTb,1U6KEQuL5wPJZMR0iHvzqh,7u1P36qRqrSNrXAp98cyp1,1aM9ClS0qz0Fp2BjmbM72M,11iIikXxC6NP0Ma8vMD27x,73vWnvPaf0yNifYIkadY9N,4J4wYsDnJxldGxAiFpIIzT:
#  None, reason: None
# ERROR:spotipy.client:HTTP Error for GET to https://api.spotify.com/v1/audio-features/?ids=7Dd6g7T930jxR3NcQnJjwp,2O7OjNCjqflzWOTVg9UlEm,6tMRhn8hTFJm2A87tmjJPr,6jtqO14L18plBtpDTtUkFR,1xcbBJGVb2TfqL39E3tAuh,1OJO3vsGqwbIQuLPGeY2Sb,2BLkpiR7oE09eY8DHUk6Bx,1vYf97tjbKVPXHK4oQPU0T,1HpBm13TNcyMW3PoUrlZPv,5BxzqNLhwISk6IN5RZFkt8,0XfwXFXOI7oys9rsZ2sjrt,1Q5kgpp4pmyGqPwNBzkSrw,0BEM16TPjHAX0nkdlLARLS,70lTzeGfLs0GnIpte9MlNE,5z2F9FkKdhd9HOSTI1GxRq,59s74rmbVxLQxjnzQ6Whkd,5fgLlepwOuApu2Cjej7EyG,63wEUQ8SN2S8nx2r21zTnl,52dwm4IBErZyShQ2CCU6yK,7E5pDQN3D93OxPak6Esnw7,1CtKHwDqsH3ctcCCI18N0g,6vXiqeYFjrNfj5dBwbC4iP,5nEdwtSv0qqeE0l4o1lR4q,0k2GOhqsrxDTAbFFSdNJjT,5O4erNlJ74PIF6kGol1ZrC,6JRLFiX9NJSoRRKxowlBYr,6bK9BH9Ts8Gj5JFvnQkzak,7yFvSYKk3g5g8e7Ffl16ws,3GIChxHmuLmBm5PTNZGDtj,2JKlf0IYz5oWsT3OCLyjpO,2fXLhLA7cPYEmQ1NbeAtBD,4eamJr2k9YDH8j58RSTmSc,0QCIpQV3twfqo9kh0t8Zza,5uqQyRJV8qLt8zEqnvsBVK,4fxF8ljwryMZX5c9EKrLFE,7oNgPClUYdscWWHa5PF1gT,4uOKFydzAejjSFqYbv1XPt,1UL8GkVAs6UcWF6BZ3DYZt,0xeoETh1ChVy1k7TGAS9O8,3Cx9j78Z0NE6jYwBWvvV3P,2le9fblYnfoLr9dkZIsJUa,0Jur3mZsQba3vqSpcmsOPm,3h5TiWTqGxjSjFrbruPFH9,5lJx5eiSahFfsqkMJVlkDN,1zW2csx1vVJrKfvDrFQNVt,1HGyhNaRUFEDBiVLbvtbL6,7BfW1eoDh27W69nxsmRicb,22AbXxQbMdVqEz7xJjhccG,6PbtTwGUPPbnT7nRTA1gS3,5UnrKDpkTDKUAB3yM2Pu3X,09Nck1nvRcg1Y14SNfWwtJ,3a3EDrWejkryzeGFkPypOR,58dGRQrNmAJeRMFuguUbvD,63iwhg49U6FgWtTDzkEVnL,0INtJm8gCJKtNaAYQNVlpZ,7wCgKgkuthR3K568qESxDp,1p2ea5Dy0tOnt9q4wfy4aX,35cWnQKyLjmzkq81M51D9n,1QhrlNjzqmqEFW5T5yMFhw,3mtukCAgd0mE260QcBfXAX,0vtJ9Dq53hfXE3KyP1yPni,4paJ10JPNCyOaLtz2cY928,7vggqxNKwd6xdRoYS0pQtM,4fHDlIntTsRGSyTg5UYZYC,1Rvl8qsKJurfFTyWLBI9ib,1AO26gK1sI6PoFY9eUF8yV,193RlTGibelHrNqyAMEbLl,1Gsv8f8KmowkF5BnfMIGKy,0KtKac3tvjeGjg6FXcUy7X,0nEUaCsD5tDZjbY7tMAaea,4cs6ORX8aKd6rtVdwAnnel,1nXTM2CVdaoCySSD5kgt3J,4PvVHAkONOaS6v4wgONGYZ,7nT9lGk3bf5rvnVbzPIE3N,2fiWS5wuP9WKFPLWK92aNC,4jvxHT21eXgvjiPtCxH7Mx,3AEZUABDXNtecAOSC1qTfo,6iOqw5oLWwkFp76kGciRLQ,30qIkGvUtmSAwcMkC2K36g,1NyiB5s6uBWUjZffvWjEmo,3D7cUXDEKLAFsoD10QRoiR,5YH1A3YttSay4lgAR75tk3,2D3z17LBMJ2HEHeBFFjTLi,5igUhyuNinXVuTqtrg300z,2hnMS47jN0etwvFPzYk11f,1ATZfYmZOcm24vl5oQtPdC,1j3ANZgokEc0jKztEDV34l,2CoGg71SqwNgriNkOLClae,6FAD8Eq8ukoOja8KOxklLZ,6yVkakCN460KOVol9ZazjH,2eAGNnEr6mrviKoi9wEzWd,4Qmbc7KFWkKvxBz5KjcA6g,05pIwhbiRdGHSxy8roUv9y,79utbmnooe9qk40k9NRPcR,748pETtPvRIotGU9N3FgXH,3d1yZsoVQvUqsZPlYBLvKn,5t1pVRGTlueob96zAoEJ8D,2vo0kfh9mZIUe2WsqYkFGb,0hr9CoeDSUMmQQ7ZgTLRzh,0yGqZ7gtfNOjteyIp17rCb with Params: {} returned 403 due to None
# WARNING:recommender:audio features batch error: http status: 403, code: -1 - https://api.spotify.com/v1/audio-features/?ids=7Dd6g7T930jxR3NcQnJjwp,2O7OjNCjqflzWOTVg9UlEm,6tMRhn8hTFJm2A87tmjJPr,6jtqO14L18plBtpDTtUkFR,1xcbBJGVb2TfqL39E3tAuh,1OJO3vsGqwbIQuLPGeY2Sb,2BLkpiR7oE09eY8DHUk6Bx,1vYf97tjbKVPXHK4oQPU0T,1HpBm13TNcyMW3PoUrlZPv,5BxzqNLhwISk6IN5RZFkt8,0XfwXFXOI7oys9rsZ2sjrt,1Q5kgpp4pmyGqPwNBzkSrw,0BEM16TPjHAX0nkdlLARLS,70lTzeGfLs0GnIpte9MlNE,5z2F9FkKdhd9HOSTI1GxRq,59s74rmbVxLQxjnzQ6Whkd,5fgLlepwOuApu2Cjej7EyG,63wEUQ8SN2S8nx2r21zTnl,52dwm4IBErZyShQ2CCU6yK,7E5pDQN3D93OxPak6Esnw7,1CtKHwDqsH3ctcCCI18N0g,6vXiqeYFjrNfj5dBwbC4iP,5nEdwtSv0qqeE0l4o1lR4q,0k2GOhqsrxDTAbFFSdNJjT,5O4erNlJ74PIF6kGol1ZrC,6JRLFiX9NJSoRRKxowlBYr,6bK9BH9Ts8Gj5JFvnQkzak,7yFvSYKk3g5g8e7Ffl16ws,3GIChxHmuLmBm5PTNZGDtj,2JKlf0IYz5oWsT3OCLyjpO,2fXLhLA7cPYEmQ1NbeAtBD,4eamJr2k9YDH8j58RSTmSc,0QCIpQV3twfqo9kh0t8Zza,5uqQyRJV8qLt8zEqnvsBVK,4fxF8ljwryMZX5c9EKrLFE,7oNgPClUYdscWWHa5PF1gT,4uOKFydzAejjSFqYbv1XPt,1UL8GkVAs6UcWF6BZ3DYZt,0xeoETh1ChVy1k7TGAS9O8,3Cx9j78Z0NE6jYwBWvvV3P,2le9fblYnfoLr9dkZIsJUa,0Jur3mZsQba3vqSpcmsOPm,3h5TiWTqGxjSjFrbruPFH9,5lJx5eiSahFfsqkMJVlkDN,1zW2csx1vVJrKfvDrFQNVt,1HGyhNaRUFEDBiVLbvtbL6,7BfW1eoDh27W69nxsmRicb,22AbXxQbMdVqEz7xJjhccG,6PbtTwGUPPbnT7nRTA1gS3,5UnrKDpkTDKUAB3yM2Pu3X,09Nck1nvRcg1Y14SNfWwtJ,3a3EDrWejkryzeGFkPypOR,58dGRQrNmAJeRMFuguUbvD,63iwhg49U6FgWtTDzkEVnL,0INtJm8gCJKtNaAYQNVlpZ,7wCgKgkuthR3K568qESxDp,1p2ea5Dy0tOnt9q4wfy4aX,35cWnQKyLjmzkq81M51D9n,1QhrlNjzqmqEFW5T5yMFhw,3mtukCAgd0mE260QcBfXAX,0vtJ9Dq53hfXE3KyP1yPni,4paJ10JPNCyOaLtz2cY928,7vggqxNKwd6xdRoYS0pQtM,4fHDlIntTsRGSyTg5UYZYC,1Rvl8qsKJurfFTyWLBI9ib,1AO26gK1sI6PoFY9eUF8yV,193RlTGibelHrNqyAMEbLl,1Gsv8f8KmowkF5BnfMIGKy,0KtKac3tvjeGjg6FXcUy7X,0nEUaCsD5tDZjbY7tMAaea,4cs6ORX8aKd6rtVdwAnnel,1nXTM2CVdaoCySSD5kgt3J,4PvVHAkONOaS6v4wgONGYZ,7nT9lGk3bf5rvnVbzPIE3N,2fiWS5wuP9WKFPLWK92aNC,4jvxHT21eXgvjiPtCxH7Mx,3AEZUABDXNtecAOSC1qTfo,6iOqw5oLWwkFp76kGciRLQ,30qIkGvUtmSAwcMkC2K36g,1NyiB5s6uBWUjZffvWjEmo,3D7cUXDEKLAFsoD10QRoiR,5YH1A3YttSay4lgAR75tk3,2D3z17LBMJ2HEHeBFFjTLi,5igUhyuNinXVuTqtrg300z,2hnMS47jN0etwvFPzYk11f,1ATZfYmZOcm24vl5oQtPdC,1j3ANZgokEc0jKztEDV34l,2CoGg71SqwNgriNkOLClae,6FAD8Eq8ukoOja8KOxklLZ,6yVkakCN460KOVol9ZazjH,2eAGNnEr6mrviKoi9wEzWd,4Qmbc7KFWkKvxBz5KjcA6g,05pIwhbiRdGHSxy8roUv9y,79utbmnooe9qk40k9NRPcR,748pETtPvRIotGU9N3FgXH,3d1yZsoVQvUqsZPlYBLvKn,5t1pVRGTlueob96zAoEJ8D,2vo0kfh9mZIUe2WsqYkFGb,0hr9CoeDSUMmQQ7ZgTLRzh,0yGqZ7gtfNOjteyIp17rCb:
#  None, reason: None
# ERROR:spotipy.client:HTTP Error for GET to https://api.spotify.com/v1/audio-features/?ids=0UIgkZSpC2O3cl2Ta2Yo67,0HGazYiDdPTL6oN93Aw2if,4BHpFqcqVrLpsGGh4Mz9h9,32wrcAmmrWqvf6nzBMrOK1,2TktkzfozZifbQhXjT6I33,5SruEBX3KpgpDvEcIuN53P,66YywMJbAgzQrGkFKjnSsK,3cPoiK69oQ1SdbB2j2ulGm,36vmaZyO0iAE6FZ7287fg2,3BntzKsnLf2pc0dsvE3Zav,1sVBT215CDmVJvfy1E2OCU,6kopmMZiyLmw7h66uXcXR7,0bRXwKfigvpKZUurwqAlEh,3zBhihYUHBmGd2bcQIobrF,1k1Bqnv2R0uJXQN4u6LKYt,6tHVEMyRfxGgQuXRzl2yOF,3Vd4fHzwS6pBS3muymjiDi,5LxvwujISqiB8vpRYv887S,1PHPODXYdkxmU9nkrqLd8y,3hhbDnFUb2bicI2df6VurK,56DxR1jHbX6xlGwZdUuN0v,4R5GN0mBvb6jkRj3Zvyhkl,65GbQI9VDTs7vo6MJL2iJA,1XwbJNPOcLuSRTQNR9zz4r,28HadeGsalBfbVfMEkCcF7,72YttnPRxyHe8zCG50jYhj,5uuJruktM9fMdN9Va0DUMl,4Hhv2vrOTy89HFRcjU3QOx,6IAuH3hgTRpUUdmOGubXGS,14qNHvX8h6HoynFuV0RxWS,2VjXGuPVVxyhMgER3Uz2Fe,63xdwScd1Ai1GigAwQxE8y,4Yu2vdSKkFrBM5agrx5XRN,0M7oki70AV10Ztt3HyUd8Z,24ntSW3QVJzR79lHAAOTaY,4DPx5423HjiwbHZ7WEBN2t,56pHllZT7QOacB0bP56ofx,7pv80uUHfocFqfTytu1MVi,1h2xVEoJORqrg71HocgqXd,3M8FzayQWtkvOhqMn2V4T2,1Omt5bfz1tZUCqd26HxbS0,4pNiE4LCVV74vfIBaUHm1b,0kzhMZZNmxiLG7qyJhVBHB,15yaPgTazHHemSnHYYl8HO,1Gy9Ofi7nPnNf3kGWPjurm,0Ss50OU9tCozI7JIywkv14,66TRwr5uJwPt15mfFkzhbi,4HlFJV71xXKIGcU3kRyttv,1zrmtymT2qkj2AQLNVemAh,2puHJmjL4jvO19aEA7kzcb,3arKRnq9OUd7yq6LRwVW8I,5yc59J3MR3tVDPTOgwgRI5,7a014uMHF3nlqzXCxV551C,7aZSo66HyYSIKWwcm6mKoD,4nzaIFFDcgEXcDagSgqE6H,6ATrsVaZT7XjkCynxM8cTS,73ZSUS3WLluxgASR1Hp74B,55WLWX71YkHt2tSucNIf1g,1CruCvvFpvyiefcWYf0lEj,5vN7P248A5pcoyttfnLiO3,2UQKDP9RhnnyGhWo6dYIkb,4tGbZjNFJLPTtw5CAwRjUP,3CbiuLMBPM6uV4a7HvkOib,4Q3HsJwY1NV2Jh5jL4knaf,6v8mOtpRlXbG3BOauqPRHC,2Xdc6qyaFBJZ8QW1KhpVci,29udRWpKTQUjkPZZkliBVl,3vCUelLOtiuNF78p9LNWZF,2q4rjDy9WhaN3o9MvDbO21,2Akdoc20by0smFu6EvVnhw,3TQxkQsyJS03EUwl02Qaub,4eGHlplaq1ME8oetnTuFFf,0Jw3cPBXlGnA6DEJrZSTI0,4aX78cL9ySD2GNGHbQLnIu,5c3PqlUjVvTwGaDwVniUNb,0N9b7upoCixmvrsF0e4XN3,0lYvegwRSOD7I38DjyiAZT,3lzYx9dpCNw6CkttQe6SlE with Params: {} returned 403 due to None
# WARNING:recommender:audio features batch error: http status: 403, code: -1 - https://api.spotify.com/v1/audio-features/?ids=0UIgkZSpC2O3cl2Ta2Yo67,0HGazYiDdPTL6oN93Aw2if,4BHpFqcqVrLpsGGh4Mz9h9,32wrcAmmrWqvf6nzBMrOK1,2TktkzfozZifbQhXjT6I33,5SruEBX3KpgpDvEcIuN53P,66YywMJbAgzQrGkFKjnSsK,3cPoiK69oQ1SdbB2j2ulGm,36vmaZyO0iAE6FZ7287fg2,3BntzKsnLf2pc0dsvE3Zav,1sVBT215CDmVJvfy1E2OCU,6kopmMZiyLmw7h66uXcXR7,0bRXwKfigvpKZUurwqAlEh,3zBhihYUHBmGd2bcQIobrF,1k1Bqnv2R0uJXQN4u6LKYt,6tHVEMyRfxGgQuXRzl2yOF,3Vd4fHzwS6pBS3muymjiDi,5LxvwujISqiB8vpRYv887S,1PHPODXYdkxmU9nkrqLd8y,3hhbDnFUb2bicI2df6VurK,56DxR1jHbX6xlGwZdUuN0v,4R5GN0mBvb6jkRj3Zvyhkl,65GbQI9VDTs7vo6MJL2iJA,1XwbJNPOcLuSRTQNR9zz4r,28HadeGsalBfbVfMEkCcF7,72YttnPRxyHe8zCG50jYhj,5uuJruktM9fMdN9Va0DUMl,4Hhv2vrOTy89HFRcjU3QOx,6IAuH3hgTRpUUdmOGubXGS,14qNHvX8h6HoynFuV0RxWS,2VjXGuPVVxyhMgER3Uz2Fe,63xdwScd1Ai1GigAwQxE8y,4Yu2vdSKkFrBM5agrx5XRN,0M7oki70AV10Ztt3HyUd8Z,24ntSW3QVJzR79lHAAOTaY,4DPx5423HjiwbHZ7WEBN2t,56pHllZT7QOacB0bP56ofx,7pv80uUHfocFqfTytu1MVi,1h2xVEoJORqrg71HocgqXd,3M8FzayQWtkvOhqMn2V4T2,1Omt5bfz1tZUCqd26HxbS0,4pNiE4LCVV74vfIBaUHm1b,0kzhMZZNmxiLG7qyJhVBHB,15yaPgTazHHemSnHYYl8HO,1Gy9Ofi7nPnNf3kGWPjurm,0Ss50OU9tCozI7JIywkv14,66TRwr5uJwPt15mfFkzhbi,4HlFJV71xXKIGcU3kRyttv,1zrmtymT2qkj2AQLNVemAh,2puHJmjL4jvO19aEA7kzcb,3arKRnq9OUd7yq6LRwVW8I,5yc59J3MR3tVDPTOgwgRI5,7a014uMHF3nlqzXCxV551C,7aZSo66HyYSIKWwcm6mKoD,4nzaIFFDcgEXcDagSgqE6H,6ATrsVaZT7XjkCynxM8cTS,73ZSUS3WLluxgASR1Hp74B,55WLWX71YkHt2tSucNIf1g,1CruCvvFpvyiefcWYf0lEj,5vN7P248A5pcoyttfnLiO3,2UQKDP9RhnnyGhWo6dYIkb,4tGbZjNFJLPTtw5CAwRjUP,3CbiuLMBPM6uV4a7HvkOib,4Q3HsJwY1NV2Jh5jL4knaf,6v8mOtpRlXbG3BOauqPRHC,2Xdc6qyaFBJZ8QW1KhpVci,29udRWpKTQUjkPZZkliBVl,3vCUelLOtiuNF78p9LNWZF,2q4rjDy9WhaN3o9MvDbO21,2Akdoc20by0smFu6EvVnhw,3TQxkQsyJS03EUwl02Qaub,4eGHlplaq1ME8oetnTuFFf,0Jw3cPBXlGnA6DEJrZSTI0,4aX78cL9ySD2GNGHbQLnIu,5c3PqlUjVvTwGaDwVniUNb,0N9b7upoCixmvrsF0e4XN3,0lYvegwRSOD7I38DjyiAZT,3lzYx9dpCNw6CkttQe6SlE:
#  None, reason: None
# audio features: 0 fetched, 1178 missing
# saved 1178 tracks and 22350 interactions
# tracks: (1178, 17), interactions: (22350, 4)

# %%
print("=== Tracks sample ===")
print(tracks_df.head(3).to_string())
print(f"\nGenres: {tracks_df['genre'].nunique()}, Artists: {tracks_df['artist_id'].nunique()}")

print("\n=== Interactions sample ===")
print(interactions_df.head(3).to_string())

n_users = interactions_df["user_id"].nunique()
n_tracks = tracks_df["track_id"].nunique()
sparsity = 1.0 - len(interactions_df) / (n_users * n_tracks)
print(f"\nUsers: {n_users}, Tracks: {n_tracks}, Interactions: {len(interactions_df)}")
print(f"Sparsity: {sparsity:.4f} ({sparsity*100:.1f}%)")

# quick validation
assert not tracks_df["track_id"].duplicated().any(), "duplicate track_ids"
assert not tracks_df["track_id"].isna().any(), "null track_ids"
assert (interactions_df["play_count"] >= 1).all(), "play_count < 1"
orphans = set(interactions_df["track_id"]) - set(tracks_df["track_id"])
assert len(orphans) == 0, f"{len(orphans)} orphan tracks"
print("\nValidation passed")
# Out:
# === Tracks sample ===
#                  track_id                 track_name               artist_id  artist_name genre  popularity  duration_ms  release_year  danceability    energy   valence       tempo  acousticness  instrumentalness  loudness  speechiness  liveness
# 0  3qhlB30KknSejmIvZZLjOD           End of Beginning  5p9HO3XC5P3BLxJs5Mtrhm          Djo   pop          50       159245          2022      0.724377  0.566801  0.660036  134.108471      0.000000          0.000000 -5.244319     0.024701  0.118656
# 1  6sGIMrtIzQjdzNndVxe397  So Easy (To Fall In Love)  00x1fYSGhdqScXBRpSj3DW  Olivia Dean   pop          50       169000          2025      0.631756  0.720352  0.662223  120.990460      0.240179          0.057401 -7.218585     0.079500  0.043289
# 2  68lbSrXDORS51pmyjZv712                       SWIM  3Nrfpe0tUJi4K4DXYWgMUX          BTS   pop          50       159007          2026      0.770276  0.646006  0.585211  109.786057      0.247803          0.007638 -6.356656     0.021829  0.162585
#
# Genres: 15, Artists: 707
#
# === Interactions sample ===
#      user_id                track_id  play_count   timestamp
# 0  user_0000  0synZpsRWT8bQ8Fz4nPpM3           1  1718923288
# 1  user_0000  3cohjFTLMRmx8xQbd5dpX5           2  1702190212
# 2  user_0000  2NXHPV7sQrCs8uwcG24fXf           9  1715630174
#
# Users: 500, Tracks: 1178, Interactions: 22350
# Sparsity: 0.9621 (96.2%)
#
# Validation passed

# %% [markdown]
# ### Exploratory Data Analysis

# %%
interactions_per_user = interactions_df.groupby("user_id").size()
interactions_per_track = interactions_df.groupby("track_id").size()

fig, axes = plt.subplots(2, 2, figsize=(14, 10))

axes[0, 0].hist(interactions_per_user, bins=40, color="#1DB954", edgecolor="white", alpha=0.85)
axes[0, 0].set_title("Interactions per User", fontweight="bold")
axes[0, 0].set_xlabel("# interactions")

genre_counts = tracks_df["genre"].value_counts()
axes[0, 1].barh(genre_counts.index[:15], genre_counts.values[:15], color="#1DB954", edgecolor="white")
axes[0, 1].set_title("Tracks per Genre", fontweight="bold")
axes[0, 1].invert_yaxis()

axes[1, 0].hist(tracks_df["popularity"], bins=40, color="#191414", edgecolor="white", alpha=0.85)
axes[1, 0].set_title("Track Popularity Distribution", fontweight="bold")

axes[1, 1].hist(interactions_per_track, bins=40, color="#1DB954", edgecolor="white", alpha=0.85)
axes[1, 1].set_yscale("log")
axes[1, 1].set_title("Interactions per Track (log)", fontweight="bold")

plt.tight_layout()
plt.savefig("artifacts/figures/eda_overview.png", dpi=150, bbox_inches="tight")
plt.show()

# audio feature distributions
fig, axes = plt.subplots(3, 3, figsize=(15, 12))
for i, feat in enumerate(AUDIO_FEATURES):
    ax = axes[i // 3, i % 3]
    ax.hist(tracks_df[feat], bins=40, color="#1DB954", edgecolor="white", alpha=0.85)
    ax.set_title(feat.capitalize(), fontweight="bold")
plt.tight_layout()
plt.savefig("artifacts/figures/audio_features.png", dpi=150, bbox_inches="tight")
plt.show()

# correlation heatmap
fig, ax = plt.subplots(figsize=(10, 8))
corr = tracks_df[AUDIO_FEATURES].corr()
im = ax.imshow(corr, cmap="RdYlGn", vmin=-1, vmax=1, aspect="auto")
ax.set_xticks(range(len(AUDIO_FEATURES)))
ax.set_yticks(range(len(AUDIO_FEATURES)))
ax.set_xticklabels(AUDIO_FEATURES, rotation=45, ha="right")
ax.set_yticklabels(AUDIO_FEATURES)
plt.colorbar(im, ax=ax)
ax.set_title("Audio Feature Correlations", fontweight="bold")
plt.tight_layout()
plt.savefig("artifacts/figures/feature_correlation.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Preprocessing and Feature Engineering

# %%
# clean interactions
valid_track_ids = set(tracks_df["track_id"])
interactions_clean = interactions_df[interactions_df["track_id"].isin(valid_track_ids)].copy()
interactions_clean = interactions_clean.groupby(["user_id", "track_id"], as_index=False).agg(
    play_count=("play_count", "sum"),
    timestamp=("timestamp", "max"),
)
print(f"Cleaned interactions: {len(interactions_clean)}")

# temporal split per user
df_sorted = interactions_clean.sort_values("timestamp")
train_rows, val_rows, test_rows = [], [], []

for uid, group in df_sorted.groupby("user_id"):
    n = len(group)
    n_test = max(1, int(n * cfg.test_ratio))
    n_val = max(1, int(n * cfg.val_ratio))
    n_train = n - n_test - n_val
    if n_train < 1:
        train_rows.append(group)
        continue
    train_rows.append(group.iloc[:n_train])
    val_rows.append(group.iloc[n_train:n_train + n_val])
    test_rows.append(group.iloc[n_train + n_val:])

train_df = pd.concat(train_rows, ignore_index=True)
val_df = pd.concat(val_rows, ignore_index=True) if val_rows else pd.DataFrame(columns=df_sorted.columns)
test_df = pd.concat(test_rows, ignore_index=True) if test_rows else pd.DataFrame(columns=df_sorted.columns)
print(f"Split: train={len(train_df)}, val={len(val_df)}, test={len(test_df)}")

# id mappings
users = sorted(interactions_clean["user_id"].unique())
tracks = sorted(interactions_clean["track_id"].unique())
user2idx = {u: i for i, u in enumerate(users)}
idx2user = {i: u for u, i in user2idx.items()}
track2idx = {t: i for i, t in enumerate(tracks)}
idx2track = {i: t for t, i in track2idx.items()}

# sparse interaction matrix (train only)
rows = train_df["user_id"].map(user2idx).values
cols = train_df["track_id"].map(track2idx).values
values = 1.0 + 0.5 * np.log1p(train_df["play_count"].values)
train_matrix = csr_matrix((values, (rows, cols)), shape=(len(user2idx), len(track2idx)))
print(f"Interaction matrix: {train_matrix.shape}, nnz={train_matrix.nnz}, density={train_matrix.nnz / (train_matrix.shape[0] * train_matrix.shape[1]):.4f}")

# audio feature matrix
indexed = tracks_df.set_index("track_id").loc[
    [t for t, _ in sorted(track2idx.items(), key=lambda x: x[1])]
]
feature_matrix = indexed[AUDIO_FEATURES].values.astype(np.float64)
scaler = StandardScaler()
feature_matrix = scaler.fit_transform(feature_matrix)

# track popularity from training data
popularity = train_df.groupby("track_id")["play_count"].sum()
track_popularity = np.zeros(len(track2idx))
for tid, count in popularity.items():
    if tid in track2idx:
        track_popularity[track2idx[tid]] = count
if track_popularity.max() > 0:
    track_popularity /= track_popularity.max()

# user consumed sets
user_consumed_train = {}
for uid, group in train_df.groupby("user_id"):
    user_consumed_train[uid] = set(group["track_id"])

# save processed splits
train_df.to_csv("data/processed/train.csv", index=False)
val_df.to_csv("data/processed/val.csv", index=False)
test_df.to_csv("data/processed/test.csv", index=False)
save_artifact(scaler, Path("data/processed/feature_scaler.joblib"))

print("Preprocessing done")
# Out:
# Cleaned interactions: 22350
# Split: train=16058, val=2016, test=4276
# Interaction matrix: (500, 1178), nnz=16058, density=0.0273
# Preprocessing done

# %%
# genre TF-IDF features
ordered_tracks = sorted(track2idx.items(), key=lambda x: x[1])
genre_texts = []
for tid, _ in ordered_tracks:
    row = tracks_df[tracks_df["track_id"] == tid].iloc[0]
    genre_texts.append(row["genre"] + " " + row["artist_name"])

tfidf = TfidfVectorizer(max_features=100)
genre_features = tfidf.fit_transform(genre_texts).toarray()
print(f"Genre TF-IDF: {genre_features.shape}")

# combined features (audio 70% + genre 30%)
audio_norm = normalize(feature_matrix, norm="l2")
genre_norm = normalize(genre_features, norm="l2")
combined_features = normalize(np.hstack([audio_norm * 0.7, genre_norm * 0.3]), norm="l2")
print(f"Combined features: {combined_features.shape}")

# user profiles: weighted avg of consumed track features
user_ids_sorted = sorted(train_df["user_id"].unique())
user2uidx = {u: i for i, u in enumerate(user_ids_sorted)}
user_profiles = np.zeros((len(user_ids_sorted), combined_features.shape[1]))

for uid, group in train_df.groupby("user_id"):
    uidx = user2uidx[uid]
    vectors, weights = [], []
    timestamps = group["timestamp"].values
    ts_norm = (timestamps - timestamps.min()) / max(1, timestamps.max() - timestamps.min())
    for j, (_, row) in enumerate(group.iterrows()):
        if row["track_id"] in track2idx:
            tidx = track2idx[row["track_id"]]
            recency = 0.5 + 0.5 * (ts_norm[j] if j < len(ts_norm) else 1.0)
            weights.append(np.log1p(row["play_count"]) * recency)
            vectors.append(combined_features[tidx])
    if vectors:
        w = np.array(weights)
        w /= w.sum()
        user_profiles[uidx] = np.average(vectors, axis=0, weights=w)

print(f"User profiles: {user_profiles.shape}")
# Out:
# Genre TF-IDF: (1178, 100)
# Combined features: (1178, 109)
# User profiles: (500, 109)

# %% [markdown]
# ### Collaborative Filtering (Truncated SVD)
#
# Matrix factorization on the sparse user-item interaction matrix. Decomposes into latent user and item factors, recommendations via dot product in the latent space.

# %%
class CollaborativeFilter:
    def __init__(self, n_components=50):
        self.n_components = n_components
        self.svd = TruncatedSVD(n_components=n_components, random_state=cfg.random_seed)
        self.user_factors = None
        self.item_factors = None
        self.is_fitted = False

    def fit(self, interaction_matrix):
        self.user_factors = self.svd.fit_transform(interaction_matrix)
        self.item_factors = self.svd.components_.T
        self.user_factors = normalize(self.user_factors, norm="l2")
        self.item_factors = normalize(self.item_factors, norm="l2")
        explained = self.svd.explained_variance_ratio_.sum()
        print(f"SVD fitted: {interaction_matrix.shape}, explained variance: {explained:.4f}")
        self.is_fitted = True

    def predict_scores(self, user_idx):
        return self.user_factors[user_idx] @ self.item_factors.T

    def recommend(self, user_idx, n=10, exclude_indices=None):
        scores = self.predict_scores(user_idx)
        if exclude_indices:
            for idx in exclude_indices:
                scores[idx] = -np.inf
        top = np.argsort(scores)[::-1][:n]
        return [(int(i), float(scores[i])) for i in top]


collab = CollaborativeFilter(n_components=cfg.svd_n_components)
collab.fit(train_matrix)
save_artifact(collab, Path("artifacts/models/collaborative.joblib"))

# quick test
sample_uid = user2idx[users[0]]
sample_recs = collab.recommend(sample_uid, n=5)
print(f"\nSample collab recs for {users[0]}:")
for tidx, score in sample_recs:
    tid = idx2track[tidx]
    t = tracks_df[tracks_df["track_id"] == tid].iloc[0]
    print(f"  {t['track_name']} by {t['artist_name']} [{t['genre']}] score={score:.4f}")
# Out:
# SVD fitted: (500, 1178), explained variance: 0.3241
#
# Sample collab recs for user_0000:
#   Blue's Clues Theme Song by Blues Clues [blues] score=0.7539
#   Hook by Blues Traveler [blues] score=0.6881
#   The Blues Man by Hank Williams, Jr. [blues] score=0.6651
#   Stone's Throw by The Red Clay Strays [blues] score=0.6331
#   In Hell I'll Be in Good Company by The Dead South [blues] score=0.5636

# %% [markdown]
# ### Content-Based Filtering

# %%
class ContentBasedFilter:
    def __init__(self):
        self.feature_matrix = None
        self.similarity_matrix = None
        self.user_profiles = None
        self.is_fitted = False

    def fit(self, feature_matrix, user_profiles=None):
        self.feature_matrix = normalize(feature_matrix, norm="l2")
        self.user_profiles = normalize(user_profiles, norm="l2") if user_profiles is not None else None
        if feature_matrix.shape[0] <= 10_000:
            self.similarity_matrix = cosine_similarity(self.feature_matrix)
        self.is_fitted = True
        print(f"Content model fitted: {feature_matrix.shape[0]} tracks, {feature_matrix.shape[1]} features")

    def similar_tracks(self, track_idx, n=10, exclude_indices=None):
        scores = self.similarity_matrix[track_idx].copy() if self.similarity_matrix is not None else \
            cosine_similarity(self.feature_matrix[track_idx:track_idx+1], self.feature_matrix)[0]
        scores[track_idx] = -np.inf
        if exclude_indices:
            for idx in exclude_indices:
                scores[idx] = -np.inf
        top = np.argsort(scores)[::-1][:n]
        return [(int(i), float(scores[i])) for i in top]

    def recommend_for_user(self, user_idx, n=10, exclude_indices=None):
        profile = self.user_profiles[user_idx:user_idx+1]
        scores = cosine_similarity(profile, self.feature_matrix)[0]
        if exclude_indices:
            for idx in exclude_indices:
                scores[idx] = -np.inf
        top = np.argsort(scores)[::-1][:n]
        return [(int(i), float(scores[i])) for i in top]

    def recommend_from_seeds(self, seed_indices, n=10, exclude_indices=None):
        seed_vecs = self.feature_matrix[seed_indices]
        profile = normalize(seed_vecs.mean(axis=0, keepdims=True), norm="l2")
        scores = cosine_similarity(profile, self.feature_matrix)[0]
        exclude = set(seed_indices)
        if exclude_indices:
            exclude |= exclude_indices
        for idx in exclude:
            scores[idx] = -np.inf
        top = np.argsort(scores)[::-1][:n]
        return [(int(i), float(scores[i])) for i in top]


content = ContentBasedFilter()
content.fit(combined_features, user_profiles)
save_artifact(content, Path("artifacts/models/content_based.joblib"))
# Out:
# Content model fitted: 1178 tracks, 109 features

# %%
# similar tracks test
sample_track = tracks_df["track_id"].iloc[min(100, len(tracks_df) - 1)]
sample_tidx = track2idx[sample_track]
similar = content.similar_tracks(sample_tidx, n=5)

t_info = tracks_df[tracks_df["track_id"] == sample_track].iloc[0]
print(f"Similar to: {t_info['track_name']} by {t_info['artist_name']} [{t_info['genre']}]\n")
for tidx, score in similar:
    tid = idx2track[tidx]
    t = tracks_df[tracks_df["track_id"] == tid].iloc[0]
    print(f"  {t['track_name']} by {t['artist_name']} [{t['genre']}] sim={score:.4f}")
# Out:
# Similar to: Numb by Linkin Park [rock]
#
#   One Step Closer by Linkin Park [metal] sim=0.8742
#   What I've Done by Linkin Park [metal] sim=0.8616
#   Rock The Boat by Aaliyah [rock] sim=0.8587
#   Rock You Like A Hurricane by Scorpions [rock] sim=0.8329
#   505 by Arctic Monkeys [rock] sim=0.8305

# %% [markdown]
# ### Hybrid Fusion, Ranking, and Real-time Session Layer
#
# Weighted score fusion for warm users (60% collaborative, 40% content), content+popularity fallback for cold start, re-ranking with diversity constraints, and session-based profile adjustment for real-time updates.

# %%
def _normalize_scores(scores):
    if not scores:
        return {}
    vals = [s for _, s in scores]
    mn, mx = min(vals), max(vals)
    rng = mx - mn if mx > mn else 1.0
    return {idx: (score - mn) / rng for idx, score in scores}


class HybridRecommender:
    def __init__(self, collab_model, content_model, track_popularity,
                 collab_weight=0.6, content_weight=0.4, cold_threshold=5):
        self.collab = collab_model
        self.content = content_model
        self.track_popularity = track_popularity
        self.collab_weight = collab_weight
        self.content_weight = content_weight
        self.cold_threshold = cold_threshold

    def recommend(self, user_idx=None, n=10, exclude_indices=None,
                  n_consumed=0, seed_track_indices=None, mode="hybrid"):
        exclude = exclude_indices or set()
        candidate_n = n * 5

        is_cold = user_idx is None or n_consumed < self.cold_threshold

        if mode == "collaborative" and user_idx is not None:
            recs = self.collab.recommend(user_idx, n, exclude)
            return [(idx, score, "collaborative") for idx, score in recs]

        if mode == "content" and user_idx is not None:
            recs = self.content.recommend_for_user(user_idx, n, exclude)
            return [(idx, score, "content") for idx, score in recs]

        if mode == "popularity":
            return self._pop_recommend(n, exclude)

        if is_cold and seed_track_indices:
            content_recs = self.content.recommend_from_seeds(seed_track_indices, candidate_n, exclude)
            cs = _normalize_scores(content_recs)
            pop = {idx: self.track_popularity[idx] for idx in cs}
            blended = {idx: 0.8 * cs[idx] + 0.2 * pop.get(idx, 0) for idx in cs}
            return self._top_n(blended, n, "content+popularity")

        if is_cold:
            return self._pop_recommend(n, exclude)

        collab_recs = self.collab.recommend(user_idx, candidate_n, exclude)
        content_recs = self.content.recommend_for_user(user_idx, candidate_n, exclude)
        cs_collab = _normalize_scores(collab_recs)
        cs_content = _normalize_scores(content_recs)

        all_cands = set(cs_collab.keys()) | set(cs_content.keys())
        blended = {}
        for idx in all_cands:
            blended[idx] = self.collab_weight * cs_collab.get(idx, 0) + self.content_weight * cs_content.get(idx, 0)
        return self._top_n(blended, n, "hybrid")

    def _pop_recommend(self, n, exclude):
        scores = self.track_popularity.copy()
        for idx in exclude:
            scores[idx] = -np.inf
        top = np.argsort(scores)[::-1][:n]
        return [(int(i), float(scores[i]), "popularity") for i in top]

    def _top_n(self, scores, n, source):
        sorted_items = sorted(scores.items(), key=lambda x: x[1], reverse=True)[:n]
        return [(idx, score, source) for idx, score in sorted_items]


def rerank(candidates, tracks_df, idx2track, track_popularity, n=10,
           diversity_weight=0.1, popularity_weight=0.05, max_per_artist=3):
    if not candidates:
        return []

    track_lookup = tracks_df.set_index("track_id")
    scored = []
    for idx, base_score, source in candidates:
        tid = idx2track.get(idx)
        if tid is None or tid not in track_lookup.index:
            continue
        t = track_lookup.loc[tid]
        pop = track_popularity[idx] if idx < len(track_popularity) else 0
        novelty = 1.0 - pop
        adjusted = base_score + popularity_weight * pop + 0.05 * novelty
        scored.append({
            "idx": idx, "track_id": tid,
            "artist_id": t.get("artist_id", ""), "genre": t.get("genre", ""),
            "adjusted_score": adjusted, "source": source,
        })

    scored.sort(key=lambda x: x["adjusted_score"], reverse=True)

    selected = []
    artist_counts, genre_counts = {}, {}
    for item in scored:
        if len(selected) >= n:
            break
        artist = item["artist_id"]
        if artist_counts.get(artist, 0) >= max_per_artist:
            continue
        genre = item["genre"]
        genre_penalty = diversity_weight * genre_counts.get(genre, 0) / max(1, len(selected))
        item["final_score"] = item["adjusted_score"] - genre_penalty
        selected.append(item)
        artist_counts[artist] = artist_counts.get(artist, 0) + 1
        genre_counts[genre] = genre_counts.get(genre, 0) + 1

    selected.sort(key=lambda x: x["final_score"], reverse=True)
    return [(item["idx"], item["final_score"], item["source"]) for item in selected]


class RealtimeRecommender:
    def __init__(self, hybrid, content, feature_matrix, recency_boost=0.3):
        self.hybrid = hybrid
        self.content = content
        self.feature_matrix = feature_matrix
        self.recency_boost = recency_boost
        self.session_buffer = {}

    def record_interaction(self, user_idx, track_idx, timestamp=0.0):
        if user_idx not in self.session_buffer:
            self.session_buffer[user_idx] = []
        self.session_buffer[user_idx].append((track_idx, timestamp))

    def recommend_with_session(self, user_idx, n=10, exclude_indices=None, n_consumed=0):
        exclude = set(exclude_indices or set())
        if user_idx in self.session_buffer:
            for tidx, _ in self.session_buffer[user_idx]:
                exclude.add(tidx)

        session = self.session_buffer.get(user_idx, [])
        if not session:
            return self.hybrid.recommend(user_idx=user_idx, n=n, exclude_indices=exclude, n_consumed=n_consumed)

        # session-adjusted content profile
        weights = np.array([2.0 ** i for i in range(len(session))], dtype=np.float64)
        weights /= weights.sum()
        recent_vecs = np.array([self.feature_matrix[tidx] for tidx, _ in session])
        recent_profile = np.average(recent_vecs, axis=0, weights=weights)

        if self.content.user_profiles is not None and user_idx < len(self.content.user_profiles):
            original = self.content.user_profiles[user_idx]
            blended = (1 - self.recency_boost) * original + self.recency_boost * recent_profile
        else:
            blended = recent_profile

        blended = normalize(blended.reshape(1, -1), norm="l2")
        content_scores = cosine_similarity(blended, self.content.feature_matrix)[0]

        if self.hybrid.collab.is_fitted and user_idx < self.hybrid.collab.user_factors.shape[0]:
            collab_scores = self.hybrid.collab.predict_scores(user_idx)
            c_min, c_max = collab_scores.min(), collab_scores.max()
            if c_max > c_min:
                collab_scores = (collab_scores - c_min) / (c_max - c_min)
        else:
            collab_scores = np.zeros(len(content_scores))

        ct_min, ct_max = content_scores.min(), content_scores.max()
        if ct_max > ct_min:
            content_scores = (content_scores - ct_min) / (ct_max - ct_min)

        combined = self.hybrid.collab_weight * collab_scores + self.hybrid.content_weight * content_scores
        for idx in exclude:
            combined[idx] = -np.inf

        top = np.argsort(combined)[::-1][:n]
        return [(int(i), float(combined[i]), "realtime_hybrid") for i in top]


hybrid = HybridRecommender(
    collab_model=collab, content_model=content,
    track_popularity=track_popularity,
    collab_weight=cfg.collab_weight, content_weight=cfg.content_weight,
)

realtime = RealtimeRecommender(
    hybrid=hybrid, content=content, feature_matrix=combined_features,
)

print("Hybrid + ranking + realtime ready")
# Out:
# Hybrid + ranking + realtime ready

# %%
# hybrid recommendations for sample user
sample_user = users[0]
sample_uidx = user2idx[sample_user]
consumed = user_consumed_train.get(sample_user, set())
exclude = {track2idx[t] for t in consumed if t in track2idx}

candidates = hybrid.recommend(sample_uidx, n=15, exclude_indices=exclude, n_consumed=len(consumed))
ranked = rerank(candidates, tracks_df, idx2track, track_popularity, n=5)

print(f"Recs for {sample_user}:")
for idx, score, source in ranked:
    tid = idx2track[idx]
    t = tracks_df[tracks_df["track_id"] == tid].iloc[0]
    print(f"  {t['track_name']} by {t['artist_name']} [{t['genre']}] score={score:.4f} ({source})")

# simulate listening to a track and see recs update
play_track = list(track2idx.keys())[100]
realtime.record_interaction(sample_uidx, track2idx[play_track])
rt_candidates = realtime.recommend_with_session(sample_uidx, n=15, exclude_indices=exclude, n_consumed=len(consumed))
rt_ranked = rerank(rt_candidates, tracks_df, idx2track, track_popularity, n=5)

play_name = tracks_df[tracks_df["track_id"] == play_track].iloc[0]["track_name"]
print(f"\nAfter listening to {play_name}:")
for idx, score, source in rt_ranked:
    tid = idx2track[idx]
    t = tracks_df[tracks_df["track_id"] == tid].iloc[0]
    print(f"  {t['track_name']} by {t['artist_name']} [{t['genre']}] score={score:.4f} ({source})")
# Out:
# Recs for user_0000:
#   Blueslides by ScHoolboy Q [blues] score=0.6881 (hybrid)
#   The Blues Man by Hank Williams, Jr. [blues] score=0.5500 (hybrid)
#   It Ain't Right by Jessie Murph [blues] score=0.5474 (hybrid)
#   Blue Star by Treaty Oak Revival [blues] score=0.5394 (hybrid)
#   Blue's Clues & You Theme Song by Blue's Clues & You [blues] score=0.4598 (hybrid)
#
# After listening to LA CANCIÓN:
#   The Blues Man by Hank Williams, Jr. [blues] score=0.9004 (realtime_hybrid)
#   Blues in Hoss' Flat - 2003 Remaster by Count Basie [blues] score=0.7516 (realtime_hybrid)
#   Blueslides by ScHoolboy Q [blues] score=0.7464 (realtime_hybrid)
#   Forgot Your Roots by Buffalo Traffic Jam [blues] score=0.7426 (realtime_hybrid)
#   Blue Star by Treaty Oak Revival [blues] score=0.7415 (realtime_hybrid)

# %% [markdown]
# ### Offline Evaluation

# %%
def precision_at_k(recommended, relevant, k):
    hits = sum(1 for r in recommended[:k] if r in relevant)
    return hits / k if k else 0.0

def recall_at_k(recommended, relevant, k):
    if not relevant:
        return 0.0
    hits = sum(1 for r in recommended[:k] if r in relevant)
    return hits / len(relevant)

def average_precision(recommended, relevant, k):
    if not relevant:
        return 0.0
    hits, sum_p = 0, 0.0
    for i, item in enumerate(recommended[:k]):
        if item in relevant:
            hits += 1
            sum_p += hits / (i + 1)
    return sum_p / min(len(relevant), k)

def ndcg_at_k(recommended, relevant, k):
    dcg = sum(1.0 / np.log2(i + 2) for i, item in enumerate(recommended[:k]) if item in relevant)
    idcg = sum(1.0 / np.log2(i + 2) for i in range(min(len(relevant), k)))
    return dcg / idcg if idcg > 0 else 0.0

def hit_rate_at_k(recommended, relevant, k):
    return 1.0 if any(r in relevant for r in recommended[:k]) else 0.0


def evaluate_model(recommend_fn, test_df, model_name="model", k_values=None):
    if k_values is None:
        k_values = [5, 10, 20]

    test_by_user = {}
    for uid, group in test_df.groupby("user_id"):
        if uid in user2idx:
            test_by_user[uid] = {track2idx[tid] for tid in group["track_id"] if tid in track2idx}

    metrics = {f"{m}@{k}": [] for k in k_values for m in ["precision", "recall", "map", "ndcg", "hit_rate"]}
    n_eval = 0

    for uid, relevant in test_by_user.items():
        if not relevant:
            continue
        uidx = user2idx[uid]
        consumed = user_consumed_train.get(uid, set())
        exclude = {track2idx[t] for t in consumed if t in track2idx}
        try:
            recs = recommend_fn(uidx, max(k_values), exclude)
            if not recs:
                continue
            rec_indices = [r[0] for r in recs]
        except Exception:
            continue

        for k in k_values:
            metrics[f"precision@{k}"].append(precision_at_k(rec_indices, relevant, k))
            metrics[f"recall@{k}"].append(recall_at_k(rec_indices, relevant, k))
            metrics[f"map@{k}"].append(average_precision(rec_indices, relevant, k))
            metrics[f"ndcg@{k}"].append(ndcg_at_k(rec_indices, relevant, k))
            metrics[f"hit_rate@{k}"].append(hit_rate_at_k(rec_indices, relevant, k))
        n_eval += 1

    results = {key: float(np.mean(vals)) if vals else 0.0 for key, vals in metrics.items()}
    results["n_users_evaluated"] = n_eval
    results["model_name"] = model_name
    return results


# evaluate all models
def collab_rec(uidx, n, exclude): return collab.recommend(uidx, n, exclude)
def content_rec(uidx, n, exclude): return content.recommend_for_user(uidx, n, exclude)
def hybrid_rec(uidx, n, exclude): return hybrid.recommend(uidx, n, exclude, n_consumed=len(exclude))
def pop_rec(uidx, n, exclude): return hybrid._pop_recommend(n, exclude)

all_results = {}
for name, fn in [("popularity", pop_rec), ("collaborative", collab_rec),
                  ("content_based", content_rec), ("hybrid", hybrid_rec)]:
    results = evaluate_model(fn, test_df, model_name=name)
    all_results[name] = results
    save_json(results, Path(f"artifacts/metrics/{name}_metrics.json"))

save_json(all_results, Path("artifacts/metrics/all_metrics.json"))

# print results table
k_values = [5, 10, 20]
for k in k_values:
    print(f"\n{'='*80}")
    print(f"@{k}")
    print(f"{'Model':<15} {'Precision':>10} {'Recall':>10} {'MAP':>10} {'NDCG':>10} {'HitRate':>10}")
    print("-" * 65)
    for name in ["popularity", "collaborative", "content_based", "hybrid"]:
        r = all_results[name]
        print(f"{name:<15} {r[f'precision@{k}']:>10.4f} {r[f'recall@{k}']:>10.4f} "
              f"{r[f'map@{k}']:>10.4f} {r[f'ndcg@{k}']:>10.4f} {r[f'hit_rate@{k}']:>10.4f}")
# Out:
# ================================================================================
# @5
# Model            Precision     Recall        MAP       NDCG    HitRate
# -----------------------------------------------------------------
# popularity          0.0084     0.0051     0.0032     0.0077     0.0420
# collaborative       0.0568     0.0336     0.0323     0.0622     0.2480
# content_based       0.0600     0.0327     0.0314     0.0620     0.2540
# hybrid              0.0620     0.0366     0.0304     0.0619     0.2720
#
# ================================================================================
# @10
# Model            Precision     Recall        MAP       NDCG    HitRate
# -----------------------------------------------------------------
# popularity          0.0062     0.0074     0.0023     0.0073     0.0620
# collaborative       0.0604     0.0723     0.0279     0.0718     0.4340
# content_based       0.0576     0.0641     0.0259     0.0668     0.4080
# hybrid              0.0574     0.0654     0.0258     0.0665     0.3940
#
# ================================================================================
# @20
# Model            Precision     Recall        MAP       NDCG    HitRate
# -----------------------------------------------------------------
# popularity          0.0068     0.0155     0.0027     0.0110     0.1320
# collaborative       0.0594     0.1398     0.0333     0.1000     0.6340
# content_based       0.0522     0.1164     0.0295     0.0877     0.5500
# hybrid              0.0595     0.1353     0.0320     0.0968     0.6200

# %% [markdown]
# ### Saving the Engine

# %%
class RecommendationEngine:
    def __init__(self, collab, content, hybrid, realtime, tracks_df,
                 user2idx, idx2user, track2idx, idx2track,
                 track_popularity, user_consumed_train):
        self.collab = collab
        self.content = content
        self.hybrid = hybrid
        self.realtime = realtime
        self.tracks_df = tracks_df
        self.user2idx = user2idx
        self.idx2user = idx2user
        self.track2idx = track2idx
        self.idx2track = idx2track
        self.track_popularity = track_popularity
        self.user_consumed_train = user_consumed_train
        self._track_lookup = tracks_df.set_index("track_id")

    def recommend(self, user_id, n=10, seed_tracks=None, mode="hybrid", use_realtime=False):
        is_known = user_id in self.user2idx
        user_idx = self.user2idx.get(user_id)
        consumed = self.user_consumed_train.get(user_id, set())
        exclude = {self.track2idx[t] for t in consumed if t in self.track2idx}
        n_consumed = len(consumed)

        seed_indices = None
        if seed_tracks:
            seed_indices = [self.track2idx[t] for t in seed_tracks if t in self.track2idx]
            seed_indices = seed_indices or None

        if use_realtime and user_idx is not None:
            candidates = self.realtime.recommend_with_session(
                user_idx=user_idx, n=n * 3, exclude_indices=exclude, n_consumed=n_consumed)
        else:
            candidates = self.hybrid.recommend(
                user_idx=user_idx, n=n * 3, exclude_indices=exclude,
                n_consumed=n_consumed, seed_track_indices=seed_indices, mode=mode)

        ranked = rerank(candidates, self.tracks_df, self.idx2track, self.track_popularity, n=n)

        results = []
        for idx, score, source in ranked:
            tid = self.idx2track[idx]
            if tid in consumed:
                continue
            if tid in self._track_lookup.index:
                t = self._track_lookup.loc[tid]
                results.append({
                    "track_id": tid, "track_name": t["track_name"],
                    "artist_name": t["artist_name"], "genre": t["genre"],
                    "score": round(score, 4) if np.isfinite(score) else 0.0,
                    "source": source,
                })
        return {"user_id": user_id, "recommendations": results, "mode": mode,
                "is_cold_start": not is_known or n_consumed < 5}

    def similar_tracks(self, track_id, n=10):
        if track_id not in self.track2idx:
            return []
        tidx = self.track2idx[track_id]
        similar = self.content.similar_tracks(tidx, n)
        results = []
        for idx, score in similar:
            tid = self.idx2track[idx]
            if tid in self._track_lookup.index:
                t = self._track_lookup.loc[tid]
                results.append({
                    "track_id": tid, "track_name": t["track_name"],
                    "artist_name": t["artist_name"], "genre": t["genre"],
                    "score": round(score, 4), "source": "content_similarity",
                })
        return results

    def record_interaction(self, user_id, track_id):
        if user_id in self.user2idx and track_id in self.track2idx:
            self.realtime.record_interaction(self.user2idx[user_id], self.track2idx[track_id])

    def get_user_ids(self):
        return list(self.user2idx.keys())

    def get_track_ids(self):
        return list(self.track2idx.keys())


engine = RecommendationEngine(
    collab=collab, content=content, hybrid=hybrid, realtime=realtime,
    tracks_df=tracks_df,
    user2idx=user2idx, idx2user=idx2user,
    track2idx=track2idx, idx2track=idx2track,
    track_popularity=track_popularity,
    user_consumed_train=user_consumed_train,
)

save_artifact(engine, Path("artifacts/models/engine.joblib"))
print("Engine saved to artifacts/models/engine.joblib")
# Out:
# Engine saved to artifacts/models/engine.joblib

# %%
# sample recommendations
response = engine.recommend(users[0], n=5)
print(f"Recommendations for {users[0]} (mode={response['mode']}, cold_start={response['is_cold_start']}):")
for rec in response["recommendations"]:
    print(f"  {rec['track_name']} by {rec['artist_name']} [{rec['genre']}] "
          f"score={rec['score']:.4f} ({rec['source']})")

# similar tracks
sim_track = tracks_df["track_id"].iloc[min(50, len(tracks_df) - 1)]
sim_name = tracks_df.loc[tracks_df["track_id"] == sim_track, "track_name"].iloc[0]
print(f"\nSimilar to {sim_name}:")
for item in engine.similar_tracks(sim_track, n=5):
    print(f"  {item['track_name']} by {item['artist_name']} [{item['genre']}] sim={item['score']:.4f}")

# to serve with fastapi, run: python pipeline.py
# it starts a server at http://localhost:8000
# Out:
# Recommendations for user_0000 (mode=hybrid, cold_start=False):
#   Blueslides by ScHoolboy Q [blues] score=0.6881 (hybrid)
#   The Blues Man by Hank Williams, Jr. [blues] score=0.5500 (hybrid)
#   It Ain't Right by Jessie Murph [blues] score=0.5474 (hybrid)
#   Blue Star by Treaty Oak Revival [blues] score=0.5394 (hybrid)
#   Blue's Clues & You Theme Song by Blue's Clues & You [blues] score=0.4598 (hybrid)
#
# Similar to POP DAT THANG:
#   Good Luck, Babe! by Chappell Roan [pop] sim=0.9351
#   My Own Worst Enemy by Lit [pop] sim=0.9254
#   End of Beginning by Djo [pop] sim=0.8960
#   Stateside + Zara Larsson by PinkPantheress [pop] sim=0.8937
#   BIRDS OF A FEATHER by Billie Eilish [pop] sim=0.8930
